# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import create_engine, inspect
import pandas as pd

# %%
# Create the engine
engine = create_engine("sqlite:///Resources/fastfood_nutritional_info.db")

# %%
# reflect an existing database into a new model
Base = automap_base()

# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['categories', 'menu_items', 'nutrition', 'restaurants']

# %%
#Save references to each table
Categories = Base.classes.categories
Menu_items = Base.classes.menu_items
Restaurants = Base.classes.restaurants
Nutrition = Base.classes.nutrition

# %%
# Create a session
session = Session(engine)

# %%
# Create a inspector
inspector = inspect(engine)

# %%
# Inspect Nurition
Nutrition_columns = inspector.get_columns('Nutrition')
for column in Nutrition_columns:
    print(column['name'], column["type"])
# Out:
# restaurant_id INTEGER
# category_id INTEGER
# item_id INTEGER
# serving_size_oz INTEGER
# calories INTEGER
# calories_from_fat INTEGER
# total_fat_g INTEGER
# total_fat_%_dv INTEGER
# saturated_fat_g INTEGER
# saturated_fat_%_dv INTEGER
# trans_fat_g INTEGER
# cholesterol_mg INTEGER
# cholesterol_%_dv INTEGER
# sodium_mg INTEGER
# sodium_%_dv INTEGER
# carbohydrates_g INTEGER
# carbohydrates_%_dv INTEGER
# dietary_fiber_g INTEGER
# dietary_fiber_% _dv INTEGER
# sugars_g INTEGER
# protein_g INTEGER
# vitamin_a_%_dv INTEGER
# vitamin_c_%_dv INTEGER
# calcium_%_dv INTEGER
# iron_%_dv INTEGER

# %%
# Inspect Restaurants
Restaurants_columns = inspector.get_columns('Restaurants')
for column in Restaurants_columns:
    print(column['name'], column["type"])
# Out:
# id INTEGER
# name TEXT

# %%
# Inspect Categories
Categories_columns = inspector.get_columns('Categories')
for column in Categories_columns:
    print(column['name'], column["type"])
# Out:
# category_name TEXT
# id INTEGER

# %%
# Inspect Menu Items
Items_columns = inspector.get_columns('Menu_items')
for column in Items_columns:
    print(column['name'], column["type"])
# Out:
# item_name TEXT
# id INTEGER

# %% [markdown]
# # Queries

# %% [markdown]
# ## Test Queries (for troubleshooting)

# %%
# List serving size (nutrition table)
Nutrition_test = session.query(Nutrition.serving_size_oz).order_by(Nutrition.serving_size_oz.desc()).all()
Nutrition_test
# Out:
# [(32),
#  (32),
#  (32),
#  (32),
#  (32),
#  (30),
#  (30),
#  (30),
#  (30),
#  (30),
#  (30),
#  (30),
#  (27.266802),
#  (25.996938),
#  (22.8),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (22),
#  (21.51714),
#  (21),
#  (21),
#  (21),
#  (21),
#  (21),
#  (21),
#  (21),
#  (20),
#  (20),
#  (20),
#  (20),
#  (20),
#  (20),
#  (20),
#  (20),
#  (20),
#  (20),
#  (20),
#  (20),
#  (20),
#  (20),
#  (20),
#  (20),
#  (18.025014),
#  (16.9),
#  (16.2),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (16),
#  (15.4),
#  (15.3),
#  (15.16782),
#  (15.061997999999999),
#  (14.9),
#  (14.8),
#  (14.427066),
#  (14.2),
#  (13.897956),
#  (13.439394),
#  (13.439394),
#  (13.439394),
#  (13.4),
#  (13.22775),
#  (13.157202),
#  (13.086654),
#  (13.05138),
#  (12.910284),
#  (12.839736),
#  (12.769188),
#  (12.733914),
#  (12.663366),
#  (12.663366),
#  (12.628092),
#  (12.416447999999999),
#  (12.416447999999999),
#  (12.381174),
#  (12.310626),
#  (12.3),
#  (12.240078),
#  (12.134256),
#  (12.134256),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (12),
#  (11.81679),
#  (11.81679),
#  (11.81679),
#  (11.8),
#  (11.4),
#  (11.2),
#  (11.1),
#  (11.1),
#  (11.076036),
#  (11.076036),
#  (10.970214),
#  (10.9),
#  (10.9),
#  (10.829118),
#  (10.829118),
#  (10.7),
#  (10.7),
#  (10.5),
#  (10.300008),
#  (10.3),
#  (10.158912),
#  (10.1),
#  (10.1),
#  (10.05309),
#  (10.017816),
#  (10),
#  (10),
#  (10),
#  (9.6),
#  (9.6),
#  (9.6),
#  (9.559254),
#  (9.5),
#  (9.5),
#  (9.5),
#  (9.34761),
#  (9.241788),
#  (9),
#  (8.8),
#  (8.712678),
#  (8.6),
#  (8.5),
#  (8.5),
#  (8.46576),
#  (8.3),
#  (8.3),
#  (8.254116),
#  (8.254116),
#  (8.218842),
#  (8.218842),
#  (8.1),
#  (8.1),
#  (8),
#  (7.980103999999999),
#  (7.980103999999999),
#  (7.971924),
#  (7.93665),
#  (7.9),
#  (7.866102),
#  (7.725006),
#  (7.725006),
#  (7.619184),
#  (7.6),
#  (7.513362),
#  (7.513362),
#  (7.5),
#  (7.478088),
#  (7.4),
#  (7.336992),
#  (7.336992),
#  (7.336992),
#  (7.3),
#  (7.3),
#  (7.23117),
#  (7.23117),
#  (7.2),
#  (7.1),
#  (7.1),
#  (7.1),
#  (7.1),
#  (7.1),
#  (7),
#  (6.984252),
#  (6.9),
#  (6.8),
#  (6.70206),
#  (6.7),
#  (6.7),
#  (6.5),
#  (6.455142),
#  (6.4),
#  (6.4),
#  (6.3),
#  (6.3),
#  (6.3),
#  (6.2),
#  (6.1),
#  (6),
#  (6),
#  (5.9),
#  (5.9),
#  (5.9),
#  (5.8),
#  (5.714388),
#  (5.7),
#  (5.7),
#  (5.7),
#  (5.7),
#  (5.7),
#  (5.7),
#  (5.7),
#  (5.679114),
#  (5.6),
#  (5.6),
#  (5.5),
#  (5.4),
#  (5.3),
#  (5.3),
#  (5.2),
#  (5.2),
#  (5.2),
#  (5.1),
#  (5),
#  (5),
#  (5),
#  (4.8),
#  (4.8),
#  (4.6),
#  (4.6),
#  (4.5),
#  (4.3),
#  (4.3),
#  (4.3),
#  (4.1),
#  (4.1),
#  (4),
#  (4),
#  (3.9),
#  (3.9),
#  (3.9),
#  (3.597948),
#  (3.597948),
#  (3.5),
#  (3.4),
#  (3.1),
#  (3.068838),
#  (2.786646),
#  (2.7),
#  (2.680824),
#  (2.64555),
#  (2.64555),
#  (2.64555),
#  (2.64555),
#  (2.64555),
#  (2.6),
#  (2.504454),
#  (2.504454),
#  (2.398632),
#  (2.3),
#  (2.29281),
#  (2.257536),
#  (2.257536),
#  (2.186988),
#  (2),
#  (1.798974),
#  (1.657878),
#  (1.657878),
#  (1.657878),
#  (1.657878),
#  (1.58733),
#  (1.58733),
#  (1.58733),
#  (1.58733),
#  (1.58733),
#  (1.58733),
#  (1.58733),
#  (1.58733),
#  (1.3),
#  (1.23459),
#  (1.23459),
#  (1.2),
#  (1.164042),
#  (1.164042),
#  (1),
#  (0.740754),
#  (0.634932),
#  (0.634932),
#  (0.634932),
#  (0.52911),
#  (0.52911),
#  (0.52911),
#  (0.52911),
#  (0.493836),
#  (0.493836),
#  (0.493836),
#  (0.493836),
#  (0.493836),
#  (0.493836),
#  (0.493836),
#  (0.493836),
#  (0.493836),
#  (0.493836),
#  (0.493836),
#  (0.493836),
#  (0.493836),
#  (0.493836),
#  (0.38801399999999997),
#  (0.38801399999999997),
#  (0.317466),
#  (0.246918),
#  (0.246918),
#  (0.246918),
#  (0.17637),
#  (0.141096),
#  (0.141096),
#  (0.141096),
#  (0.105822),
#  (0.035274),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None),
#  (None)]

# %%
# List restaurants
restaurants_test = session.query(Restaurants.id, Restaurants.name).order_by(Restaurants.id.desc()).all()
restaurants_test
# Out:
# [(3000, 'starbucks'), (2000, 'subway'), (1000, 'mcdonalds')]

# %%
# List categories 
categories_test = session.query(Categories.category_name).order_by(Categories.id.desc()).all()
categories_test
# Out:
# [('Other Food'),
#  ('Desert'),
#  ('Frappuccino® Blended Crème'),
#  ('Frappuccino® Light Blended Coffee'),
#  ('Frappuccino® Blended Coffee'),
#  ('Smoothies'),
#  ('Shaken Iced Beverages'),
#  ('Tazo® Tea Drinks'),
#  ('Signature Espresso Drinks'),
#  ('Classic Espresso Drinks'),
#  ('Coffee'),
#  ('Seasonings'),
#  ('Protein'),
#  ('Veggies'),
#  ('Sauces'),
#  ('Extras'),
#  ('Cheese'),
#  ('Bread'),
#  ('Wrap'),
#  ('Extra'),
#  ('Salad'),
#  ('Sandwich'),
#  ('Smoothies & Shakes'),
#  ('Coffee & Tea'),
#  ('Beverages'),
#  ('Desserts'),
#  ('Snacks & Sides'),
#  ('Salads'),
#  ('Chicken & Fish'),
#  ('Beef & Pork'),
#  ('Breakfast')]

# %%
# List menu items
Items_test2 = session.query(Menu_items.item_name).order_by(Menu_items.id.desc()).all()
Items_test2
# Out:
# [('Seasonal Fruit Blend'),
#  ('Organic Avocado (Spread)'),
#  ('Lemon Chiffon Yogurt'),
#  ("Justin's Classic Almond Butter"),
#  ("Justin's Chocolate Hazelnut Butter"),
#  ('Fresh Blueberries and Honey Greek Yogurt Parfait'),
#  ('Berry Trio Yogurt'),
#  ('Turkey Pesto Panini'),
#  ('Turkey & Havarti Sandwich'),
#  ('Roasted Tomato & Mozzarella Panini'),
#  ('Lentils & Vegetable Protein Bowl with Brown Rice'),
#  ('Italian-Style Ham & Spicy Salami'),
#  ('Homestyle Chicken & Double-Smoked Bacon'),
#  ('Egg Salad Sandwich'),
#  ('Chicken BLT Salad Sandwich'),
#  ('Chicken Artichoke on Ancient Grain Flatbread'),
#  ('Chicken & Quinoa Protein Bowl with Black Beans and Greens'),
#  ('Ancho Chipotle Chicken Panini'),
#  ('Spinach Feta & Cage Free Egg White Breakfast Wrap'),
#  ('Spicy Chorizo  Monterey Jack & Egg Breakfast Sandwich'),
#  ('Sous Vide Egg Bites: Egg White & Red Pepper'),
#  ('Sous Vide Egg Bites: Bacon & Gruyere'),
#  ('Slow-Roasted Ham Swiss & Egg Breakfast Sandwich'),
#  ('Seared Steak Egg & Tomatillo Wrap'),
#  ('Sausage Cheddar & Egg Breakfast Sandwich'),
#  ('Reduced-Fat Turkey Bacon & Cage Free Egg White Breakfast Sandwich'),
#  ('Hearty Blueberry Oatmeal'),
#  ('Ham & Cheese Croissant'),
#  ('Double-Smoked Bacon Cheddar & Egg Sandwich'),
#  ('Classic Whole-Grain Oatmeal'),
#  ('Certified Gluten-Free Breakfast Sandwich'),
#  ('Bacon Gouda & Egg Breakfast Sandwich'),
#  ('Pirate Cake Pop'),
#  ('Chocolate Chip Cookie Dough Cake Pop'),
#  ('Chocolate Cake Pop'),
#  ('Birthday Cake Pop'),
#  ('Smoked Turkey Protein Box'),
#  ('PB&J Protein Box'),
#  ('Eggs & Cheese Protein Box'),
#  ('Chicken Wrap Protein Box'),
#  ('Cheese & Fruit Protein Box'),
#  ('BBQ Chicken Protein Box'),
#  ("Za'atar Chicken & Lemon Tahini Salad"),
#  ('Turkey & Fire-Roasted Corn Salad'),
#  ('Smoked Mozzarella & Roasted Pepper Sandwich'),
#  ("Slow-Roasted Ham & Beecher's Flagship Cheese Small Sandwich"),
#  ('Seared Steak & Cheddar Sandwich'),
#  ('Roasted Turkey & Dill Havarti Sandwich'),
#  ('Roasted Carrot & Kale Side Salad'),
#  ('Honey BBQ Sriracha Chicken Sandwich'),
#  ('Herbed Chicken & Fig Spread Small Sandwich'),
#  ('Green Goddess Avocado Salad'),
#  ('Garden Greens & Shaved Parmesan Side Salad'),
#  ("Farmers' Market Protein Box"),
#  ('Cubano Sandwich'),
#  ('Cauliflower Tabbouleh Side Salad'),
#  ('Cage-Free Eggs & Seasoned Grains Side Salad'),
#  ('Burrata & Basil Pesto Small Sandwich'),
#  ('Strawberries & Jam Sandwich'),
#  ('Volpi™ Pepperoni & Tomato Savory Foldover'),
#  ('Vermont Maple Walnut Muffin'),
#  ('Vanilla Bean Whoopie Pie'),
#  ('Toffeedoodle'),
#  ('The Classic - Bantam Bagels (2 Pack)'),
#  ('Strawberry Cake Pop'),
#  ('Sprouted Grain Vegan Bagel'),
#  ("S'mores Bar Multipack"),
#  ("S'mores Bar"),
#  ('Reduced-Fat Cinnamon Swirl Coffee Cake'),
#  ('Raspberry Whoopie Pie'),
#  ('Raspberry Swirl Loaf Cake'),
#  ('Pumpkin Bread'),
#  ('Plain Bagel'),
#  ('Petite Vanilla Bean Scone'),
#  ('Pecan Tart'),
#  ('Peanut butter cup cookie'),
#  ('Old-Fashioned Glazed Doughnut'),
#  ('Octopus Cookie'),
#  ('Oatmeal Cookie'),
#  ('Multigrain Bagel'),
#  ('Michigan Cherry Oat Bar'),
#  ('Iced Lemon Pound Cake'),
#  ('Ice Cream Cone Sugar Cookie'),
#  ('Gluten-Free Marshmallow Dream Bar'),
#  ('French Toast - Bantam Bagels (2 Pack)'),
#  ('Frappuccino® Cookie Straw'),
#  ('Everything Bagel with Cheese'),
#  ("Everybody's Favorite - Bantam Bagel (2 Pack)"),
#  ('Double Chocolate Loaf Cake'),
#  ('Double Chocolate Chunk Brownie'),
#  ('Double Chocolate Brownie'),
#  ("Devil's Food Doughnut"),
#  ('Cranberry Orange Scone'),
#  ('Cookie Butter Bar'),
#  ('Classic Coffee Cake'),
#  ('Cinnamon Raisin Bagel'),
#  ('Cinnamon Morning Bun'),
#  ('Chocolate Marble Loaf Cake'),
#  ('Chocolate Hazelnut Croissant'),
#  ('Chocolate Croissant'),
#  ('Chocolate Chunk Muffin'),
#  ('Starbucks Chocolate Chip Cookie'),
#  ('Chewy Chocolate Cookie'),
#  ('Cheese Danish'),
#  ('Butterfly Cookie'),
#  ('Butter Croissant'),
#  ('Blueberry Scone'),
#  ('Blueberry Muffin with Yogurt and Honey'),
#  ('Banana Nut Bread'),
#  ('Apple Fritter'),
#  ('Almond Croissant'),
#  ('8-Grain Roll'),
#  ('Chonga Bagel'),
#  ('Vanilla Bean (Without Whipped Cream)-Grande Nonfat Milk'),
#  ('Vanilla Bean (Without Whipped Cream)-Tall Soymilk'),
#  ('Vanilla Bean (Without Whipped Cream)-Tall  Whole Milk'),
#  ('Vanilla Bean (Without Whipped Cream)-Tall Nonfat Milk'),
#  ('Strawberries & Crème (Without Whipped Cream)-Venti  Soymilk'),
#  ('Strawberries & Crème (Without Whipped Cream)-Venti Whole Milk'),
#  ('Strawberries & Crème (Without Whipped Cream)-Venti Nonfat Milk'),
#  ('Strawberries & Crème (Without Whipped Cream)-Grande Soymilk'),
#  ('Strawberries & Crème (Without Whipped Cream)-Grande Whole Milk'),
#  ('Strawberries & Crème (Without Whipped Cream)-Grande Nonfat Milk'),
#  ('Strawberries & Crème (Without Whipped Cream)-Tall  Soymilk'),
#  ('Strawberries & Crème (Without Whipped Cream)-Tall  Whole Milk'),
#  ('Strawberries & Crème (Without Whipped Cream)-Tall Nonfat Milk'),
#  ('Java Chip-Venti Nonfat Milk'),
#  ('Java Chip-Grande Nonfat Milk'),
#  ('Java Chip-Tall Nonfat Milk'),
#  ('Caramel-Venti Nonfat Milk'),
#  ('Caramel-Grande Nonfat Milk'),
#  ('Caramel-Tall Nonfat Milk'),
#  ('Mocha-Venti Nonfat Milk'),
#  ('Mocha-Grande Nonfat Milk'),
#  ('Mocha-Tall Nonfat Milk'),
#  ('Light Blended Coffee-Venti Nonfat Milk'),
#  ('Light Blended Coffee-Grande Nonfat Milk'),
#  ('Light Blended Coffee-Tall Nonfat Milk'),
#  ('Java Chip (Without Whipped Cream)-Venti Soymilk'),
#  ('Java Chip (Without Whipped Cream)-Venti  Whole Milk'),
#  ('Java Chip (Without Whipped Cream)-Venti Nonfat Milk'),
#  ('Java Chip (Without Whipped Cream)-Grande Soymilk'),
#  ('Java Chip (Without Whipped Cream)-Grande Whole Milk'),
#  ('Java Chip (Without Whipped Cream)-Grande Nonfat Milk'),
#  ('Java Chip (Without Whipped Cream)-Tall Soymilk'),
#  ('Java Chip (Without Whipped Cream)-Tall Whole Milk'),
#  ('Java Chip (Without Whipped Cream)-Tall Nonfat Milk'),
#  ('Caramel (Without Whipped Cream)-Venti  Soymilk'),
#  ('Caramel (Without Whipped Cream)-Venti Whole Milk'),
#  ('Caramel (Without Whipped Cream)-Venti Nonfat Milk'),
#  ('Caramel (Without Whipped Cream)-Grande Soymilk'),
#  ('Caramel (Without Whipped Cream)-Grande Whole Milk'),
#  ('Caramel (Without Whipped Cream)-Grande Nonfat Milk'),
#  ('Caramel (Without Whipped Cream)-Tall Soymilk'),
#  ('Caramel (Without Whipped Cream)-Tall Whole Milk'),
#  ('Caramel (Without Whipped Cream)-Tall Nonfat Milk'),
#  ('Mocha (Without Whipped Cream)-Venti Soymilk'),
#  ('Mocha (Without Whipped Cream)-Venti Whole Milk'),
#  ('Mocha (Without Whipped Cream)-Venti Nonfat Milk'),
#  ('Mocha (Without Whipped Cream)-Grande Soymilk'),
#  ('Mocha (Without Whipped Cream)-Grande Whole Milk'),
#  ('Mocha (Without Whipped Cream)-Grande Nonfat Milk'),
#  ('Mocha (Without Whipped Cream)-Tall Soymilk'),
#  ('Mocha (Without Whipped Cream)-Tall Whole Milk'),
#  ('Mocha (Without Whipped Cream)-Tall Nonfat Milk'),
#  ('Coffee-Venti  Soymilk'),
#  ('Coffee-Venti Whole Milk'),
#  ('Coffee-Venti Nonfat Milk'),
#  ('Coffee-Grande Soymilk'),
#  ('Coffee-Grande Whole Milk'),
#  ('Coffee-Grande Nonfat Milk'),
#  ('Coffee-Tall Soymilk'),
#  ('Coffee-Tall Whole Milk'),
#  ('Coffee-Tall Nonfat Milk'),
#  ('Strawberry Banana Smoothie-Grande Soymilk'),
#  ('Strawberry Banana Smoothie-Grande 2% Milk'),
#  ('Strawberry Banana Smoothie-Grande Nonfat Milk'),
#  ('Orange Mango Banana Smoothie-Tall Soymilk'),
#  ('Orange Mango Banana Smoothie-Tall 2% Milk'),
#  ('Orange Mango Banana Smoothie-Tall Nonfat Milk'),
#  ('Banana Chocolate Smoothie-Grande Soymilk'),
#  ('Banana Chocolate Smoothie-Grande 2% Milk'),
#  ('Banana Chocolate Smoothie-Grande Nonfat Milk'),
#  ('Shaken Iced Tazo® Tea Lemonade (With Classic Syrup)-Venti'),
#  ('Shaken Iced Tazo® Tea Lemonade (With Classic Syrup)-Grande'),
#  ('Shaken Iced Tazo® Tea Lemonade (With Classic Syrup)-Tall'),
#  ('Shaken Iced Tazo® Tea (With Classic Syrup)-Venti'),
#  ('Shaken Iced Tazo® Tea (With Classic Syrup)-Grande'),
#  ('Shaken Iced Tazo® Tea (With Classic Syrup)-Tall'),
#  ('Iced Brewed Coffee (With Milk & Classic Syrup)-Venti  Soymilk'),
#  ('Iced Brewed Coffee (With Milk & Classic Syrup)-Venti  2% Milk'),
#  ('Iced Brewed Coffee (With Milk & Classic Syrup)-Venti Nonfat Milk'),
#  ('Iced Brewed Coffee (With Milk & Classic Syrup)-Grande Soymilk'),
#  ('Iced Brewed Coffee (With Milk & Classic Syrup)-Grande 2% Milk'),
#  ('Iced Brewed Coffee (With Milk & Classic Syrup)-Grande Nonfat Milk'),
#  ('Iced Brewed Coffee (With Milk & Classic Syrup)-Tall Soymilk'),
#  ('Iced Brewed Coffee (With Milk & Classic Syrup)-Tall  2% Milk'),
#  ('Iced Brewed Coffee (With Milk & Classic Syrup)-Tall Nonfat Milk'),
#  ('Iced Brewed Coffee (With Classic Syrup)-Venti'),
#  ('Iced Brewed Coffee (With Classic Syrup)-Grande'),
#  ('Iced Brewed Coffee (With Classic Syrup)-Tall'),
#  ('Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Venti Soymilk'),
#  ('Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Venti 2% Milk'),
#  ('Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Venti Nonfat Milk'),
#  ('Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Grande Soymilk'),
#  ('Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Grande 2% Milk'),
#  ('Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Grande Nonfat Milk'),
#  ('Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Tall Soymilk'),
#  ('Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Tall 2% Milk'),
#  ('Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Tall Nonfat Milk'),
#  ('Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Short Soymilk'),
#  ('Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Short 2% Milk'),
#  ('Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Short Nonfat Milk'),
#  ('Tazo® Full-Leaf Tea Latte-Venti Soymilk'),
#  ('Tazo® Full-Leaf Tea Latte-Venti 2% Milk'),
#  ('Tazo® Full-Leaf Tea Latte-Venti Nonfat Milk'),
#  ('Tazo® Full-Leaf Tea Latte-Grande  Soymilk'),
#  ('Tazo® Full-Leaf Tea Latte-Grande  2% Milk'),
#  ('Tazo® Full-Leaf Tea Latte-Grande Nonfat Milk'),
#  ('Tazo® Full-Leaf Tea Latte-Tall Soymilk'),
#  ('Tazo® Full-Leaf Tea Latte-Tall 2% Milk'),
#  ('Tazo® Full-Leaf Tea Latte-Tall Nonfat Milk'),
#  ('Tazo® Full-Leaf Tea Latte-Short Soymilk'),
#  ('Tazo® Full-Leaf Tea Latte-Short 2% Milk'),
#  ('Tazo® Full-Leaf Tea Latte-Short Nonfat Milk'),
#  ('Tazo® Green Tea Latte-Venti Soymilk'),
#  ('Tazo® Green Tea Latte-Venti 2% Milk'),
#  ('Tazo® Green Tea Latte-Venti Nonfat Milk'),
#  ('Tazo® Green Tea Latte-Grande Soymilk'),
#  ('Tazo® Green Tea Latte-Grande 2% Milk'),
#  ('Tazo® Green Tea Latte-Grande Nonfat Milk'),
#  ('Tazo® Green Tea Latte-Tall Soymilk'),
#  ('Tazo® Green Tea Latte-Tall 2% Milk'),
#  ('Tazo® Green Tea Latte-Tall Nonfat Milk'),
#  ('Tazo® Green Tea Latte-Short Soymilk'),
#  ('Tazo® Green Tea Latte-Short 2% Milk'),
#  ('Tazo® Green Tea Latte-Short Nonfat Milk'),
#  ('Tazo® Chai Tea Latte-Venti  Soymilk'),
#  ('Tazo® Chai Tea Latte-Venti  2% Milk'),
#  ('Tazo® Chai Tea Latte-Venti Nonfat Milk'),
#  ('Tazo® Chai Tea Latte-Grande Soymilk'),
#  ('Tazo® Chai Tea Latte-Grande 2% Milk'),
#  ('Tazo® Chai Tea Latte-Grande Nonfat Milk'),
#  ('Tazo® Chai Tea Latte-Tall  Soymilk'),
#  ('Tazo® Chai Tea Latte-Tall  2% Milk'),
#  ('Tazo® Chai Tea Latte-Tall Nonfat Milk'),
#  ('Tazo® Chai Tea Latte-Short Soymilk'),
#  ('Tazo® Chai Tea Latte-Short 2% Milk'),
#  ('Tazo® Chai Tea Latte-Short Nonfat Milk'),
#  ('Tazo® Tea-Venti'),
#  ('Tazo® Tea-Grande'),
#  ('Tazo® Tea-Tall'),
#  ('Tazo® Tea-Short'),
#  ('Caramel Apple Spice (Without Whipped Cream)-Venti'),
#  ('Caramel Apple Spice (Without Whipped Cream)-Grande'),
#  ('Caramel Apple Spice (Without Whipped Cream)-Tall'),
#  ('Caramel Apple Spice (Without Whipped Cream)-Short'),
#  ('Hot Chocolate (Without Whipped Cream)-Venti  Soymilk'),
#  ('Hot Chocolate (Without Whipped Cream)-Venti  2% Milk'),
#  ('Hot Chocolate (Without Whipped Cream)-Venti Nonfat Milk'),
#  ('Hot Chocolate (Without Whipped Cream)-Grande Soymilk'),
#  ('Hot Chocolate (Without Whipped Cream)-Grande 2% Milk'),
#  ('Hot Chocolate (Without Whipped Cream)-Grande Nonfat Milk'),
#  ('Hot Chocolate (Without Whipped Cream)-Tall  Soymilk'),
#  ('Hot Chocolate (Without Whipped Cream)-Tall  2% Milk'),
#  ('Hot Chocolate (Without Whipped Cream)-Tall Nonfat Milk'),
#  ('Hot Chocolate (Without Whipped Cream)-Short Soymilk'),
#  ('Hot Chocolate (Without Whipped Cream)-Short 2% Milk'),
#  ('Hot Chocolate (Without Whipped Cream)-Short Nonfat Milk'),
#  ('White Chocolate Mocha (Without Whipped Cream)-Venti Soymilk'),
#  ('White Chocolate Mocha (Without Whipped Cream)-Venti 2% Milk'),
#  ('White Chocolate Mocha (Without Whipped Cream)-Venti Nonfat Milk'),
#  ('White Chocolate Mocha (Without Whipped Cream)-Grande Soymilk'),
#  ('White Chocolate Mocha (Without Whipped Cream)-Grande 2% Milk'),
#  ('White Chocolate Mocha (Without Whipped Cream)-Grande Nonfat Milk'),
#  ('White Chocolate Mocha (Without Whipped Cream)-Tall  Soymilk'),
#  ('White Chocolate Mocha (Without Whipped Cream)-Tall  2% Milk'),
#  ('White Chocolate Mocha (Without Whipped Cream)-Tall Nonfat Milk'),
#  ('White Chocolate Mocha (Without Whipped Cream)-Short Soymilk'),
#  ('White Chocolate Mocha (Without Whipped Cream)-Short 2% Milk'),
#  ('White Chocolate Mocha (Without Whipped Cream)-Short Nonfat Milk'),
#  ('Caramel Macchiato-Venti Soymilk'),
#  ('Caramel Macchiato-Venti 2% Milk'),
#  ('Caramel Macchiato-Venti Nonfat Milk'),
#  ('Caramel Macchiato-Grande Soymilk'),
#  ('Caramel Macchiato-Grande 2% Milk'),
#  ('Caramel Macchiato-Grande Nonfat Milk'),
#  ('Caramel Macchiato-Tall  Soymilk'),
#  ('Caramel Macchiato-Tall  2% Milk'),
#  ('Caramel Macchiato-Tall Nonfat Milk'),
#  ('Caramel Macchiato-Short Soymilk'),
#  ('Caramel Macchiato-Short 2% Milk'),
#  ('Caramel Macchiato-Short Nonfat Milk'),
#  ('Skinny Latte (Any Flavour)-Venti Nonfat Milk'),
#  ('Skinny Latte (Any Flavour)-Grande Nonfat Milk'),
#  ('Skinny Latte (Any Flavour)-Tall Nonfat Milk'),
#  ('Skinny Latte (Any Flavour)-Short Nonfat Milk'),
#  ('Espresso-Doppio'),
#  ('Espresso-Solo'),
#  ('Cappuccino-Venti  Soymilk'),
#  ('Cappuccino-Venti  2% Milk'),
#  ('Cappuccino-Venti Nonfat Milk'),
#  ('Cappuccino-Grande Soymilk'),
#  ('Cappuccino-Grande 2% Milk'),
#  ('Cappuccino-Grande Nonfat Milk'),
#  ('Cappuccino-Tall Soymilk'),
#  ('Cappuccino-Tall 2% Milk'),
#  ('Cappuccino-Tall Nonfat Milk'),
#  ('Cappuccino-Short  Soymilk'),
#  ('Cappuccino-Short  2% Milk'),
#  ('Cappuccino-Short Nonfat Milk'),
#  ('Caffè Americano-Venti'),
#  ('Caffè Americano-Grande'),
#  ('Caffè Americano-Tall'),
#  ('Caffè Americano-Short'),
#  ('Vanilla Latte (Or Other Flavoured Latte)-Venti  Soymilk'),
#  ('Vanilla Latte (Or Other Flavoured Latte)-Venti  2% Milk'),
#  ('Vanilla Latte (Or Other Flavoured Latte)-Venti Nonfat Milk'),
#  ('Vanilla Latte (Or Other Flavoured Latte)-Grande Soymilk'),
#  ('Vanilla Latte (Or Other Flavoured Latte)-Grande 2% Milk'),
#  ('Vanilla Latte (Or Other Flavoured Latte)-Grande Nonfat Milk'),
#  ('Vanilla Latte (Or Other Flavoured Latte)-Tall  Soymilk'),
#  ('Vanilla Latte (Or Other Flavoured Latte)-Tall  2% Milk'),
#  ('Vanilla Latte (Or Other Flavoured Latte)-Tall Nonfat Milk'),
#  ('Vanilla Latte (Or Other Flavoured Latte)-Short Soymilk'),
#  ('Vanilla Latte (Or Other Flavoured Latte)-Short 2% Milk'),
#  ('Vanilla Latte (Or Other Flavoured Latte)-Short Nonfat Milk'),
#  ('Caffè Mocha (Without Whipped Cream)-Venti Soymilk'),
#  ('Caffè Mocha (Without Whipped Cream)-Venti 2% Milk'),
#  ('Caffè Mocha (Without Whipped Cream)-Venti Nonfat Milk'),
#  ('Caffè Mocha (Without Whipped Cream)-Grande  Soymilk'),
#  ('Caffè Mocha (Without Whipped Cream)-Grande  2% Milk'),
#  ('Caffè Mocha (Without Whipped Cream)-Grande Nonfat Milk'),
#  ('Caffè Mocha (Without Whipped Cream)-Tall Soymilk'),
#  ('Caffè Mocha (Without Whipped Cream)-Tall 2% Milk'),
#  ('Caffè Mocha (Without Whipped Cream)-Tall Nonfat Milk'),
#  ('Caffè Mocha (Without Whipped Cream)-Short Soymilk'),
#  ('Caffè Mocha (Without Whipped Cream)-Short 2% Milk'),
#  ('Caffè Mocha (Without Whipped Cream)-Short Nonfat Milk'),
#  ('Caffè Latte-Venti Soymilk'),
#  ('Caffè Latte-Venti 2% Milk'),
#  ('Caffè Latte-Venti Nonfat Milk'),
#  ('Caffè Latte-Grande Soymilk'),
#  ('Caffè Latte-Grande 2% Milk'),
#  ('Caffè Latte-Grande Nonfat Milk'),
#  ('Caffè Latte-Tall  Soymilk'),
#  ('Caffè Latte-Tall  2% Milk'),
#  ('Caffè Latte-Tall Nonfat Milk'),
#  ('Caffè Latte-Short Soymilk'),
#  ('Caffè Latte-Short 2% Milk'),
#  ('Caffè Latte-Short Nonfat Milk'),
#  ('Brewed Coffee-Venti Coffee'),
#  ('Brewed Coffee-Grande Coffee'),
#  ('Brewed Coffee-Tall Coffee'),
#  ('Brewed Coffee-Short Coffee'),
#  ('Parmesan Cheese-Seasonings'),
#  ('Bacon-Protein'),
#  ('Tomatoes-Veggies'),
#  ('Spinach-Veggies'),
#  ('Red Onions-Veggies'),
#  ('Pickles-Veggies'),
#  ('Lettuce-Veggies'),
#  ('Jalapenos-Veggies'),
#  ('Green Peppers-Veggies'),
#  ('Cucumbers-Veggies'),
#  ('Black Olives-Veggies'),
#  ('Banana Peppers-Veggies'),
#  ('Yellow Mustard-Sauces'),
#  ('Sweet Onion Sauce-Sauces'),
#  ('Subway® Vinaigrette-Sauces'),
#  ('Spicy Brown Mustard-Sauces'),
#  ('Savory Caesar**-Sauces'),
#  ('Regular Mayonnaise-Sauces'),
#  ('Red Wine Vinegar-Sauces'),
#  ('Ranch-Sauces'),
#  ('Oil-Sauces'),
#  ('Light Mayonnaise-Sauces'),
#  ('Honey Mustard**-Sauces'),
#  ('Chipotle Southwest-Sauces'),
#  ('Pepperoni-Extras'),
#  ('Guacamole-Extras'),
#  ('Bacon-Extras'),
#  ('Swiss**-Cheese'),
#  ('Shredded Mozzarella-Cheese'),
#  ('Provolone-Cheese'),
#  ('Pepperjack**-Cheese'),
#  ('Monterey Cheddar-Cheese'),
#  ('Cheddar**-Cheese'),
#  ('American-Cheese'),
#  ('Tomato Basil Wrap-Bread'),
#  ('Spinach Wrap-Bread'),
#  ('Rosemary & Sea Salt-Bread'),
#  ('Parmesan Oregano**-Bread'),
#  ('Monterey Cheddar**-Bread'),
#  ('Mini Italian-Bread'),
#  ('Mini 9-Grain Wheat-Bread'),
#  ('Jalapeño Cheese-Bread'),
#  ('Italian Herbs & Cheese-Bread'),
#  ('Italian-Bread'),
#  ('Hearty Italian**-Bread'),
#  ('Artisan Flatbread-Bread'),
#  ('9-Grain Wheat-Bread'),
#  ('9-Grain Honey Oat-Bread'),
#  ('Roasted Garlic-Bread'),
#  ('Veggie Delite®-Wrap'),
#  ('Turkey, Bacon & Guacamole-Wrap'),
#  ('Turkey Breast-Wrap'),
#  ('Tuna-Wrap'),
#  ('Sweet Onion Chicken Teriyaki-Wrap'),
#  ('Subway Club®-Wrap'),
#  ('Spicy Italian-Wrap'),
#  ('Savory Rotisserie-Style Chicken Caesar-Wrap'),
#  ('Rotisserie-Style Chicken-Wrap'),
#  ('Roast Beef-Wrap'),
#  ('Oven Roasted Chicken-Wrap'),
#  ('Cauliflower Fritter Curry Signature Wrap-Wrap'),
#  ('Meatball Marinara-Wrap'),
#  ('Italian B.M.T. ®-Wrap'),
#  ('Cripsy Cauliflower Ranch Signature Wrap-Wrap'),
#  ('Cold Cut Combo-Wrap'),
#  ('Chipotle Southwest Steak & Cheese-Wrap'),
#  ('Chicken & Bacon Ranch Melt-Wrap'),
#  ('Black Forest Ham-Wrap'),
#  ('BBQ Rib Signature Wrap-Wrap'),
#  ('White Chip Macadamia Nut Cookie-Extra'),
#  ('Sugar Cookie-Extra'),
#  ('Raspberry Lemonade Cookie-Extra'),
#  ('Raspberry Cheesecake Cookie-Extra'),
#  ('Pepperoni-Extra'),
#  ('Oatmeal Raisin Cookie-Extra'),
#  ('Double Chocolate-Extra'),
#  ('Dark Chocolate Cherry Cookie-Extra'),
#  ('Chocolate Chunk Cookie-Extra'),
#  ('Chocolate Chip with M&M’s ®-Extra'),
#  ('Chocolate Chip Cookie-Extra'),
#  ('Caramel Apple Cookie-Extra'),
#  ('Bacon-Extra'),
#  ('Steak, Egg & Cheese-Breakfast'),
#  ('Egg & Cheese-Breakfast'),
#  ('Black Forest Ham, Egg & Cheese-Breakfast'),
#  ('Bacon, Egg & Cheese-Breakfast'),
#  ('Veggie Delite®-Salad'),
#  ('Turkey Breast-Salad'),
#  ('Tuna-Salad'),
#  ('Sweet Onion Chicken Teriyaki-Salad'),
#  ('Subway Club®-Salad'),
#  ('Steak Club Salad-Salad'),
#  ('Steak & Cheese-Salad'),
#  ('Spicy Italian-Salad'),
#  ('Southwest Chipotle Chicken Club-Salad'),
#  ('Rotisserie-Style Chicken-Salad'),
#  ('Roast Beef-Salad'),
#  ('Oven Roasted Chicken-Salad'),
#  ('Meatball Marinara-Salad'),
#  ('Italian B.M.T. ®-Salad'),
#  ('Cold Cut Combo-Salad'),
#  ('Chicken & Bacon Ranch-Salad'),
#  ('Black Forest Ham-Salad'),
#  ('BBQ Rib-Salad'),
#  ('Veggie Delite®-Sandwich'),
#  ('Ultimate Spicy Italian-Sandwich'),
#  ('Ultimate Meatball Marinara-Sandwich'),
#  ('Turkey Breast-Sandwich'),
#  ('Turkey & Bacon Guacamole-Sandwich'),
#  ('Sweet Onion Chicken Teriyaki-Sandwich'),
#  ('Subway Club®-Sandwich'),
#  ('Steak & Cheese-Sandwich'),
#  ('Spicy Italian-Sandwich'),
#  ('Rotisserie-Style Chicken-Sandwich'),
#  ('Roast Beef-Sandwich'),
#  ('Paneer Tikka-Sandwich'),
#  ('Oven Roasted Chicken-Sandwich'),
#  ('Ultimate Steak-Sandwich'),
#  ('Steak Club-Sandwich'),
#  ('Southwest Chicken Club-Sandwich'),
#  ('Little Turkey Slider-Sandwich'),
#  ('Little Cheesesteak Slider-Sandwich'),
#  ('Italian Spice Slider-Sandwich'),
#  ('Ham & Jack Slider-Sandwich'),
#  ('Meatball Marinara-Sandwich'),
#  ('Italian B.M.T.®-Sandwich'),
#  ('Genoa Salami-Sandwich'),
#  ('Cold Cut Combo-Sandwich'),
#  ('Classic Tuna-Sandwich'),
#  ('Chicken Vindaloo-Sandwich'),
#  ('Chicken Tikka-Sandwich'),
#  ('Chicken Mango Curry-Sandwich'),
#  ('Chicken & Bacon Ranch Melt-Sandwich'),
#  ('Black Forest Ham-Sandwich'),
#  ('BBQ Rib-Sandwich'),
#  ("McFlurry with Reese's Peanut Butter Cups (Snack)"),
#  ("McFlurry with Reese's Peanut Butter Cups (Medium)"),
#  ('McFlurry with Oreo Cookies (Snack)'),
#  ('McFlurry with Oreo Cookies (Medium)'),
#  ('McFlurry with Oreo Cookies (Small)'),
#  ('McFlurry with M&M’s Candies (Snack)'),
#  ('McFlurry with M&M’s Candies (Medium)'),
#  ('McFlurry with M&M’s Candies (Small)'),
#  ('Shamrock Shake (Large)'),
#  ('Shamrock Shake (Medium)'),
#  ('Chocolate Shake (Large)'),
#  ('Chocolate Shake (Medium)'),
#  ('Chocolate Shake (Small)'),
#  ('Strawberry Shake (Large)'),
#  ('Strawberry Shake (Medium)'),
#  ('Strawberry Shake (Small)'),
#  ('Vanilla Shake (Large)'),
#  ('Vanilla Shake (Medium)'),
#  ('Vanilla Shake (Small)'),
#  ('Mango Pineapple Smoothie (Large)'),
#  ('Mango Pineapple Smoothie (Medium)'),
#  ('Mango Pineapple Smoothie (Small)'),
#  ('Strawberry Banana Smoothie (Large)'),
#  ('Strawberry Banana Smoothie (Medium)'),
#  ('Strawberry Banana Smoothie (Small)'),
#  ('Blueberry Pomegranate Smoothie (Large)'),
#  ('Blueberry Pomegranate Smoothie (Medium)'),
#  ('Blueberry Pomegranate Smoothie (Small)'),
#  ('Frappé Chocolate Chip (Large)'),
#  ('Frappé Chocolate Chip (Medium)'),
#  ('Frappé Chocolate Chip (Small)'),
#  ('Frappé Caramel (Large)'),
#  ('Frappé Caramel (Medium)'),
#  ('Frappé Caramel (Small)'),
#  ('Frappé Mocha (Large)'),
#  ('Frappé Mocha (Medium)'),
#  ('Frappé Mocha (Small)'),
#  ('Iced Nonfat Caramel Mocha (Large)'),
#  ('Iced Nonfat Caramel Mocha (Medium)'),
#  ('Iced Nonfat Caramel Mocha (Small)'),
#  ('Iced Caramel Mocha (Large)'),
#  ('Iced Caramel Mocha (Medium)'),
#  ('Iced Caramel Mocha (Small)'),
#  ('Iced Mocha with Nonfat Milk (Large)'),
#  ('Iced Mocha with Nonfat Milk (Medium)'),
#  ('Iced Mocha with Nonfat Milk (Small)'),
#  ('Iced Mocha (Large)'),
#  ('Iced Mocha (Medium)'),
#  ('Iced Mocha (Small)'),
#  ('Iced Coffee with Sugar Free French Vanilla Syrup (Large)'),
#  ('Iced Coffee with Sugar Free French Vanilla Syrup (Medium)'),
#  ('Iced Coffee with Sugar Free French Vanilla Syrup (Small)'),
#  ('French Vanilla Iced Coffee (Large)'),
#  ('French Vanilla Iced Coffee (Medium)'),
#  ('French Vanilla Iced Coffee (Small)'),
#  ('Hazelnut Iced Coffee (Large)'),
#  ('Hazelnut Iced Coffee (Medium)'),
#  ('Hazelnut Iced Coffee (Small)'),
#  ('Caramel Iced Coffee (Large)'),
#  ('Caramel Iced Coffee (Medium)'),
#  ('Caramel Iced Coffee (Small)'),
#  ('Regular Iced Coffee (Large)'),
#  ('Regular Iced Coffee (Medium)'),
#  ('Regular Iced Coffee (Small)'),
#  ('Hot Chocolate with Nonfat Milk (Large)'),
#  ('Hot Chocolate with Nonfat Milk (Medium)'),
#  ('Hot Chocolate with Nonfat Milk (Small)'),
#  ('Hot Chocolate (Large)'),
#  ('Hot Chocolate (Medium)'),
#  ('Hot Chocolate (Small)'),
#  ('Nonfat Caramel Mocha (Large)'),
#  ('Nonfat Caramel Mocha (Medium)'),
#  ('Nonfat Caramel Mocha (Small)'),
#  ('Caramel Mocha (Large)'),
#  ('Caramel Mocha (Medium)'),
#  ('Caramel Mocha (Small)'),
#  ('Mocha with Nonfat Milk (Large)'),
#  ('Mocha with Nonfat Milk (Medium)'),
#  ('Mocha with Nonfat Milk (Small)'),
#  ('Mocha (Large)'),
#  ('Mocha (Medium)'),
#  ('Mocha (Small)'),
#  ('Nonfat Latte with Sugar Free French Vanilla Syrup (Large)'),
#  ('Nonfat Latte with Sugar Free French Vanilla Syrup (Medium)'),
#  ('Nonfat Latte with Sugar Free French Vanilla Syrup (Small)'),
#  ('Nonfat French Vanilla Latte (Large)'),
#  ('Nonfat French Vanilla Latte (Medium)'),
#  ('Nonfat French Vanilla Latte (Small)'),
#  ('Nonfat Hazelnut Latte (Large)'),
#  ('Nonfat Hazelnut Latte (Medium)'),
#  ('Nonfat Hazelnut Latte (Small)'),
#  ('Nonfat Caramel Latte (Large)'),
#  ('Nonfat Caramel Latte (Medium)'),
#  ('Nonfat Caramel Latte (Small)'),
#  ('Nonfat Latte (Large)'),
#  ('Nonfat Latte (Medium)'),
#  ('Nonfat Latte (Small)'),
#  ('Latte with Sugar Free French Vanilla Syrup (Large)'),
#  ('Latte with Sugar Free French Vanilla Syrup (Medium)'),
#  ('Latte with Sugar Free French Vanilla Syrup (Small)'),
#  ('French Vanilla Latte (Large)'),
#  ('French Vanilla Latte (Medium)'),
#  ('French Vanilla Latte (Small)'),
#  ('Hazelnut Latte (Large)'),
#  ('Hazelnut Latte (Medium)'),
#  ('Hazelnut Latte (Small)'),
#  ('Caramel Latte (Large)'),
#  ('Caramel Latte (Medium)'),
#  ('Caramel Latte (Small)'),
#  ('Latte (Large)'),
#  ('Latte (Medium)'),
#  ('Latte (Small)'),
#  ('Coffee (Large)'),
#  ('Coffee (Medium)'),
#  ('Coffee (Small)'),
#  ('Sweet Tea (Child)'),
#  ('Sweet Tea (Large)'),
#  ('Sweet Tea (Medium)'),
#  ('Sweet Tea (Small)'),
#  ('Iced Tea (Child)'),
#  ('Iced Tea (Large)'),
#  ('Iced Tea (Medium)'),
#  ('Iced Tea (Small)'),
#  ('Dasani Water Bottle'),
#  ('Minute Maid Orange Juice (Large)'),
#  ('Minute Maid Orange Juice (Medium)'),
#  ('Minute Maid Orange Juice (Small)'),
#  ('Minute Maid 100% Apple Juice Box'),
#  ('Fat Free Chocolate Milk Jug'),
#  ('1% Low Fat Milk Jug'),
#  ('Sprite (Child)'),
#  ('Sprite (Large)'),
#  ('Sprite (Medium)'),
#  ('Sprite (Small)'),
#  ('Diet Dr Pepper (Child)'),
#  ('Diet Dr Pepper (Large)'),
#  ('Diet Dr Pepper (Medium)'),
#  ('Diet Dr Pepper (Small)'),
#  ('Dr Pepper (Child)'),
#  ('Dr Pepper (Large)'),
#  ('Dr Pepper (Medium)'),
#  ('Dr Pepper (Small)'),
#  ('Diet Coke (Child)'),
#  ('Diet Coke (Large)'),
#  ('Diet Coke (Medium)'),
#  ('Diet Coke (Small)'),
#  ('Coca-Cola Classic (Child)'),
#  ('Coca-Cola Classic (Large)'),
#  ('Coca-Cola Classic (Medium)'),
#  ('Coca-Cola Classic (Small)'),
#  ('Strawberry Sundae'),
#  ('Hot Caramel Sundae'),
#  ('Hot Fudge Sundae'),
#  ('Kids Ice Cream Cone'),
#  ('Oatmeal Raisin Cookie'),
#  ('Chocolate Chip Cookie'),
#  ('Baked Apple Pie'),
#  ("Fruit 'n Yogurt Parfait"),
#  ('Apple Slices'),
#  ('Side Salad'),
#  ('Kids French Fries'),
#  ('Large French Fries'),
#  ('Medium French Fries'),
#  ('Small French Fries'),
#  ('Ranch Snack Wrap (Grilled Chicken)'),
#  ('Ranch Snack Wrap (Crispy Chicken)'),
#  ('Honey Mustard Snack Wrap (Grilled Chicken)'),
#  ('Honey Mustard Snack Wrap (Crispy Chicken)'),
#  ('Chipotle BBQ Snack Wrap (Grilled Chicken)'),
#  ('Chipotle BBQ Snack Wrap (Crispy Chicken)'),
#  ('Premium Southwest Salad with Grilled Chicken'),
#  ('Premium Southwest Salad with Crispy Chicken'),
#  ('Premium Southwest Salad (without Chicken)'),
#  ('Premium Bacon Ranch Salad with Grilled Chicken'),
#  ('Premium Bacon Ranch Salad with Crispy Chicken'),
#  ('Premium Bacon Ranch Salad (without Chicken)'),
#  ('Filet-O-Fish'),
#  ('Chicken McNuggets (40 piece)'),
#  ('Chicken McNuggets (20 piece)'),
#  ('Chicken McNuggets (10 piece)'),
#  ('Chicken McNuggets (6 piece)'),
#  ('Chicken McNuggets (4 piece)'),
#  ('Premium McWrap Chicken Sweet Chili (Grilled Chicken)'),
#  ('Premium McWrap Chicken Sweet Chili (Crispy Chicken)'),
#  ('Premium McWrap Southwest Chicken (Grilled Chicken)'),
#  ('Premium McWrap Southwest Chicken (Crispy Chicken)'),
#  ('Premium McWrap Chicken & Ranch (Grilled Chicken)'),
#  ('Premium McWrap Chicken & Ranch (Crispy Chicken)'),
#  ('Premium McWrap Chicken & Bacon (Grilled Chicken)'),
#  ('Premium McWrap Chicken & Bacon (Crispy Chicken)'),
#  ('Buffalo Ranch McChicken'),
#  ('Bacon Buffalo Ranch McChicken'),
#  ('Bacon Cheddar McChicken'),
#  ('McChicken'),
#  ('Southern Style Crispy Chicken Sandwich'),
#  ('Bacon Clubhouse Grilled Chicken Sandwich'),
#  ('Bacon Clubhouse Crispy Chicken Sandwich'),
#  ('Premium Grilled Chicken Ranch BLT Sandwich'),
#  ('Premium Crispy Chicken Ranch BLT Sandwich'),
#  ('Premium Grilled Chicken Club Sandwich'),
#  ('Premium Crispy Chicken Club Sandwich'),
#  ('Premium Grilled Chicken Classic Sandwich'),
#  ('Premium Crispy Chicken Classic Sandwich'),
#  ('McRib'),
#  ('Jalapeño Double'),
#  ('Daily Double'),
#  ('Bacon McDouble'),
#  ('McDouble'),
#  ('Bacon Clubhouse Burger'),
#  ('Double Cheeseburger'),
#  ('Cheeseburger'),
#  ('Hamburger'),
#  ('Double Quarter Pounder with Cheese'),
#  ('Quarter Pounder Deluxe'),
#  ('Quarter Pounder with Bacon Habanero Ranch'),
#  ('Quarter Pounder with Bacon & Cheese'),
#  ('Quarter Pounder with Cheese'),
#  ('Big Mac'),
#  ('Fruit & Maple Oatmeal without Brown Sugar'),
#  ('Fruit & Maple Oatmeal'),
#  ('Cinnamon Melts'),
#  ('Hash Brown'),
#  ('Sausage Burrito'),
#  ('Hotcakes and Sausage'),
#  ('Hotcakes'),
#  ('Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)'),
#  ('Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)'),
#  ('Big Breakfast with Hotcakes (Large Biscuit)'),
#  ('Big Breakfast with Hotcakes (Regular Biscuit)'),
#  ('Big Breakfast with Egg Whites (Large Biscuit)'),
#  ('Big Breakfast with Egg Whites (Regular Biscuit)'),
#  ('Big Breakfast (Large Biscuit)'),
#  ('Big Breakfast (Regular Biscuit)'),
#  ('Steak, Egg & Cheese Bagel'),
#  ('Bacon, Egg & Cheese Bagel with Egg Whites'),
#  ('Bacon, Egg & Cheese Bagel'),
#  ('Sausage, Egg & Cheese McGriddles with Egg Whites'),
#  ('Sausage, Egg & Cheese McGriddles'),
#  ('Sausage McGriddles'),
#  ('Bacon, Egg & Cheese McGriddles with Egg Whites'),
#  ('Bacon, Egg & Cheese McGriddles'),
#  ('Steak & Egg Biscuit (Regular Biscuit)'),
#  ('Southern Style Chicken Biscuit (Large Biscuit)'),
#  ('Southern Style Chicken Biscuit (Regular Biscuit)'),
#  ('Sausage Biscuit with Egg Whites (Large Biscuit)'),
#  ('Sausage Biscuit with Egg Whites (Regular Biscuit)'),
#  ('Sausage Biscuit with Egg (Large Biscuit)'),
#  ('Sausage Biscuit with Egg (Regular Biscuit)'),
#  ('Sausage Biscuit (Large Biscuit)'),
#  ('Sausage Biscuit (Regular Biscuit)'),
#  ('Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)'),
#  ('Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)'),
#  ('Bacon, Egg & Cheese Biscuit (Large Biscuit)'),
#  ('Bacon, Egg & Cheese Biscuit (Regular Biscuit)'),
#  ('Steak & Egg McMuffin'),
#  ('Sausage McMuffin with Egg Whites'),
#  ('Sausage McMuffin with Egg'),
#  ('Sausage McMuffin'),
#  ('Egg White Delight'),
#  ('Egg McMuffin')]

# %% [markdown]
# ## Final Test Queries

# %%
# Which restaurant has the highest average calories?
# Testing out setting id's to be equal across tables to get the restaurant name to show up
# This is working for two queries below, but for some reason here is not returning subay or starbucks

sel = [Restaurants.name, Nutrition.restaurant_id, func.avg(Nutrition.calories)]

avg_calories = session.query(*sel).filter(Nutrition.restaurant_id==Restaurants.id).\
order_by(func.avg(Nutrition.calories).desc()).all()
avg_calories
# Out:
# [('mcdonalds', 1000, 296.14933333333335)]

# %%
# Which restaurant has the item with the highest calories?
# Testing out setting id's to be equal across tables to get the restaurant name to show up

sel = [Restaurants.name, Nutrition.restaurant_id, Nutrition.calories]

total_calories = session.query(*sel).filter(Nutrition.restaurant_id==Restaurants.id).\
order_by(Nutrition.calories.desc()).all()
total_calories
# Out:
# [('mcdonalds', 1000, 1880),
#  ('subway', 2000, 1590),
#  ('mcdonalds', 1000, 1150),
#  ('mcdonalds', 1000, 1090),
#  ('subway', 2000, 1080),
#  ('mcdonalds', 1000, 1050),
#  ('mcdonalds', 1000, 990),
#  ('mcdonalds', 1000, 940),
#  ('mcdonalds', 1000, 930),
#  ('mcdonalds', 1000, 850),
#  ('mcdonalds', 1000, 850),
#  ('mcdonalds', 1000, 820),
#  ('mcdonalds', 1000, 820),
#  ('subway', 2000, 820),
#  ('subway', 2000, 820),
#  ('subway', 2000, 820),
#  ('mcdonalds', 1000, 810),
#  ('mcdonalds', 1000, 800),
#  ('subway', 2000, 790),
#  ('subway', 2000, 780),
#  ('subway', 2000, 780),
#  ('subway', 2000, 770),
#  ('mcdonalds', 1000, 760),
#  ('subway', 2000, 760),
#  ('mcdonalds', 1000, 750),
#  ('mcdonalds', 1000, 750),
#  ('mcdonalds', 1000, 740),
#  ('subway', 2000, 730),
#  ('mcdonalds', 1000, 720),
#  ('subway', 2000, 720),
#  ('subway', 2000, 710),
#  ('mcdonalds', 1000, 700),
#  ('mcdonalds', 1000, 690),
#  ('mcdonalds', 1000, 690),
#  ('mcdonalds', 1000, 690),
#  ('subway', 2000, 680),
#  ('subway', 2000, 680),
#  ('mcdonalds', 1000, 670),
#  ('mcdonalds', 1000, 670),
#  ('mcdonalds', 1000, 670),
#  ('mcdonalds', 1000, 670),
#  ('mcdonalds', 1000, 670),
#  ('mcdonalds', 1000, 660),
#  ('mcdonalds', 1000, 660),
#  ('mcdonalds', 1000, 650),
#  ('starbucks', 3000, 650),
#  ('mcdonalds', 1000, 640),
#  ('mcdonalds', 1000, 630),
#  ('mcdonalds', 1000, 630),
#  ('mcdonalds', 1000, 620),
#  ('starbucks', 3000, 620),
#  ('mcdonalds', 1000, 610),
#  ('mcdonalds', 1000, 610),
#  ('mcdonalds', 1000, 610),
#  ('mcdonalds', 1000, 600),
#  ('subway', 2000, 600),
#  ('starbucks', 3000, 600),
#  ('starbucks', 3000, 600),
#  ('mcdonalds', 1000, 590),
#  ('subway', 2000, 580),
#  ('mcdonalds', 1000, 570),
#  ('mcdonalds', 1000, 570),
#  ('subway', 2000, 570),
#  ('starbucks', 3000, 570),
#  ('mcdonalds', 1000, 560),
#  ('subway', 2000, 560),
#  ('starbucks', 3000, 560),
#  ('starbucks', 3000, 560),
#  ('mcdonalds', 1000, 550),
#  ('mcdonalds', 1000, 550),
#  ('mcdonalds', 1000, 550),
#  ('mcdonalds', 1000, 550),
#  ('subway', 2000, 550),
#  ('subway', 2000, 550),
#  ('mcdonalds', 1000, 540),
#  ('mcdonalds', 1000, 540),
#  ('mcdonalds', 1000, 540),
#  ('mcdonalds', 1000, 540),
#  ('subway', 2000, 540),
#  ('mcdonalds', 1000, 530),
#  ('mcdonalds', 1000, 530),
#  ('mcdonalds', 1000, 530),
#  ('subway', 2000, 530),
#  ('starbucks', 3000, 530),
#  ('mcdonalds', 1000, 520),
#  ('mcdonalds', 1000, 520),
#  ('mcdonalds', 1000, 520),
#  ('mcdonalds', 1000, 520),
#  ('mcdonalds', 1000, 520),
#  ('starbucks', 3000, 520),
#  ('mcdonalds', 1000, 510),
#  ('mcdonalds', 1000, 510),
#  ('mcdonalds', 1000, 510),
#  ('mcdonalds', 1000, 510),
#  ('mcdonalds', 1000, 510),
#  ('starbucks', 3000, 510),
#  ('starbucks', 3000, 510),
#  ('mcdonalds', 1000, 500),
#  ('mcdonalds', 1000, 500),
#  ('mcdonalds', 1000, 500),
#  ('starbucks', 3000, 500),
#  ('starbucks', 3000, 500),
#  ('starbucks', 3000, 500),
#  ('starbucks', 3000, 500),
#  ('subway', 2000, 490),
#  ('subway', 2000, 490),
#  ('subway', 2000, 490),
#  ('starbucks', 3000, 490),
#  ('starbucks', 3000, 490),
#  ('starbucks', 3000, 490),
#  ('mcdonalds', 1000, 480),
#  ('mcdonalds', 1000, 480),
#  ('mcdonalds', 1000, 480),
#  ('mcdonalds', 1000, 480),
#  ('mcdonalds', 1000, 480),
#  ('subway', 2000, 480),
#  ('starbucks', 3000, 480),
#  ('starbucks', 3000, 480),
#  ('starbucks', 3000, 480),
#  ('starbucks', 3000, 480),
#  ('mcdonalds', 1000, 470),
#  ('mcdonalds', 1000, 470),
#  ('mcdonalds', 1000, 470),
#  ('starbucks', 3000, 470),
#  ('starbucks', 3000, 470),
#  ('starbucks', 3000, 470),
#  ('mcdonalds', 1000, 460),
#  ('mcdonalds', 1000, 460),
#  ('mcdonalds', 1000, 460),
#  ('mcdonalds', 1000, 460),
#  ('mcdonalds', 1000, 460),
#  ('subway', 2000, 460),
#  ('subway', 2000, 460),
#  ('starbucks', 3000, 460),
#  ('starbucks', 3000, 460),
#  ('starbucks', 3000, 460),
#  ('starbucks', 3000, 460),
#  ('starbucks', 3000, 460),
#  ('starbucks', 3000, 460),
#  ('mcdonalds', 1000, 450),
#  ('mcdonalds', 1000, 450),
#  ('mcdonalds', 1000, 450),
#  ('mcdonalds', 1000, 450),
#  ('mcdonalds', 1000, 450),
#  ('mcdonalds', 1000, 450),
#  ('subway', 2000, 450),
#  ('subway', 2000, 450),
#  ('subway', 2000, 450),
#  ('starbucks', 3000, 450),
#  ('starbucks', 3000, 450),
#  ('starbucks', 3000, 450),
#  ('starbucks', 3000, 450),
#  ('mcdonalds', 1000, 440),
#  ('mcdonalds', 1000, 440),
#  ('subway', 2000, 440),
#  ('subway', 2000, 440),
#  ('subway', 2000, 440),
#  ('starbucks', 3000, 440),
#  ('starbucks', 3000, 440),
#  ('starbucks', 3000, 440),
#  ('mcdonalds', 1000, 430),
#  ('mcdonalds', 1000, 430),
#  ('mcdonalds', 1000, 430),
#  ('mcdonalds', 1000, 430),
#  ('mcdonalds', 1000, 430),
#  ('mcdonalds', 1000, 430),
#  ('mcdonalds', 1000, 430),
#  ('mcdonalds', 1000, 430),
#  ('mcdonalds', 1000, 430),
#  ('mcdonalds', 1000, 430),
#  ('subway', 2000, 430),
#  ('subway', 2000, 430),
#  ('starbucks', 3000, 430),
#  ('starbucks', 3000, 430),
#  ('starbucks', 3000, 430),
#  ('mcdonalds', 1000, 420),
#  ('mcdonalds', 1000, 420),
#  ('subway', 2000, 420),
#  ('starbucks', 3000, 420),
#  ('starbucks', 3000, 420),
#  ('starbucks', 3000, 420),
#  ('starbucks', 3000, 420),
#  ('starbucks', 3000, 420),
#  ('starbucks', 3000, 420),
#  ('starbucks', 3000, 420),
#  ('starbucks', 3000, 420),
#  ('mcdonalds', 1000, 410),
#  ('mcdonalds', 1000, 410),
#  ('mcdonalds', 1000, 410),
#  ('mcdonalds', 1000, 410),
#  ('subway', 2000, 410),
#  ('starbucks', 3000, 410),
#  ('starbucks', 3000, 410),
#  ('starbucks', 3000, 410),
#  ('starbucks', 3000, 410),
#  ('mcdonalds', 1000, 400),
#  ('mcdonalds', 1000, 400),
#  ('mcdonalds', 1000, 400),
#  ('starbucks', 3000, 400),
#  ('mcdonalds', 1000, 390),
#  ('mcdonalds', 1000, 390),
#  ('mcdonalds', 1000, 390),
#  ('mcdonalds', 1000, 390),
#  ('starbucks', 3000, 390),
#  ('starbucks', 3000, 390),
#  ('starbucks', 3000, 390),
#  ('starbucks', 3000, 390),
#  ('starbucks', 3000, 390),
#  ('starbucks', 3000, 390),
#  ('mcdonalds', 1000, 380),
#  ('mcdonalds', 1000, 380),
#  ('mcdonalds', 1000, 380),
#  ('subway', 2000, 380),
#  ('subway', 2000, 380),
#  ('starbucks', 3000, 380),
#  ('starbucks', 3000, 380),
#  ('starbucks', 3000, 380),
#  ('mcdonalds', 1000, 370),
#  ('mcdonalds', 1000, 370),
#  ('mcdonalds', 1000, 370),
#  ('starbucks', 3000, 370),
#  ('starbucks', 3000, 370),
#  ('starbucks', 3000, 370),
#  ('starbucks', 3000, 370),
#  ('starbucks', 3000, 370),
#  ('mcdonalds', 1000, 360),
#  ('mcdonalds', 1000, 360),
#  ('mcdonalds', 1000, 360),
#  ('mcdonalds', 1000, 360),
#  ('starbucks', 3000, 360),
#  ('starbucks', 3000, 360),
#  ('starbucks', 3000, 360),
#  ('starbucks', 3000, 360),
#  ('starbucks', 3000, 360),
#  ('starbucks', 3000, 360),
#  ('starbucks', 3000, 360),
#  ('starbucks', 3000, 360),
#  ('mcdonalds', 1000, 350),
#  ('mcdonalds', 1000, 350),
#  ('mcdonalds', 1000, 350),
#  ('starbucks', 3000, 350),
#  ('starbucks', 3000, 350),
#  ('starbucks', 3000, 350),
#  ('starbucks', 3000, 350),
#  ('starbucks', 3000, 350),
#  ('starbucks', 3000, 350),
#  ('starbucks', 3000, 350),
#  ('starbucks', 3000, 350),
#  ('mcdonalds', 1000, 340),
#  ('mcdonalds', 1000, 340),
#  ('mcdonalds', 1000, 340),
#  ('mcdonalds', 1000, 340),
#  ('mcdonalds', 1000, 340),
#  ('mcdonalds', 1000, 340),
#  ('mcdonalds', 1000, 340),
#  ('mcdonalds', 1000, 340),
#  ('mcdonalds', 1000, 340),
#  ('mcdonalds', 1000, 340),
#  ('subway', 2000, 340),
#  ('subway', 2000, 340),
#  ('starbucks', 3000, 340),
#  ('starbucks', 3000, 340),
#  ('starbucks', 3000, 340),
#  ('starbucks', 3000, 340),
#  ('starbucks', 3000, 340),
#  ('mcdonalds', 1000, 330),
#  ('mcdonalds', 1000, 330),
#  ('mcdonalds', 1000, 330),
#  ('mcdonalds', 1000, 330),
#  ('mcdonalds', 1000, 330),
#  ('mcdonalds', 1000, 330),
#  ('mcdonalds', 1000, 330),
#  ('subway', 2000, 330),
#  ('subway', 2000, 330),
#  ('starbucks', 3000, 330),
#  ('starbucks', 3000, 330),
#  ('starbucks', 3000, 330),
#  ('starbucks', 3000, 330),
#  ('starbucks', 3000, 330),
#  ('starbucks', 3000, 330),
#  ('starbucks', 3000, 330),
#  ('starbucks', 3000, 330),
#  ('mcdonalds', 1000, 320),
#  ('subway', 2000, 320),
#  ('subway', 2000, 320),
#  ('starbucks', 3000, 320),
#  ('starbucks', 3000, 320),
#  ('starbucks', 3000, 320),
#  ('starbucks', 3000, 320),
#  ('starbucks', 3000, 320),
#  ('mcdonalds', 1000, 310),
#  ('mcdonalds', 1000, 310),
#  ('mcdonalds', 1000, 310),
#  ('subway', 2000, 310),
#  ('subway', 2000, 310),
#  ('starbucks', 3000, 310),
#  ('starbucks', 3000, 310),
#  ('starbucks', 3000, 310),
#  ('starbucks', 3000, 310),
#  ('starbucks', 3000, 310),
#  ('starbucks', 3000, 310),
#  ('starbucks', 3000, 310),
#  ('starbucks', 3000, 310),
#  ('starbucks', 3000, 310),
#  ('starbucks', 3000, 310),
#  ('starbucks', 3000, 310),
#  ('mcdonalds', 1000, 300),
#  ('mcdonalds', 1000, 300),
#  ('mcdonalds', 1000, 300),
#  ('subway', 2000, 300),
#  ('starbucks', 3000, 300),
#  ('starbucks', 3000, 300),
#  ('starbucks', 3000, 300),
#  ('starbucks', 3000, 300),
#  ('starbucks', 3000, 300),
#  ('starbucks', 3000, 300),
#  ('mcdonalds', 1000, 290),
#  ('mcdonalds', 1000, 290),
#  ('mcdonalds', 1000, 290),
#  ('mcdonalds', 1000, 290),
#  ('mcdonalds', 1000, 290),
#  ('subway', 2000, 290),
#  ('subway', 2000, 290),
#  ('subway', 2000, 290),
#  ('subway', 2000, 290),
#  ('starbucks', 3000, 290),
#  ('starbucks', 3000, 290),
#  ('starbucks', 3000, 290),
#  ('starbucks', 3000, 290),
#  ('starbucks', 3000, 290),
#  ('starbucks', 3000, 290),
#  ('starbucks', 3000, 290),
#  ('starbucks', 3000, 290),
#  ('starbucks', 3000, 290),
#  ('starbucks', 3000, 290),
#  ('starbucks', 3000, 290),
#  ('starbucks', 3000, 290),
#  ('mcdonalds', 1000, 280),
#  ('mcdonalds', 1000, 280),
#  ('mcdonalds', 1000, 280),
#  ('mcdonalds', 1000, 280),
#  ('mcdonalds', 1000, 280),
#  ('mcdonalds', 1000, 280),
#  ('mcdonalds', 1000, 280),
#  ('mcdonalds', 1000, 280),
#  ('mcdonalds', 1000, 280),
#  ('subway', 2000, 280),
#  ('subway', 2000, 280),
#  ('starbucks', 3000, 280),
#  ('starbucks', 3000, 280),
#  ('starbucks', 3000, 280),
#  ('starbucks', 3000, 280),
#  ('starbucks', 3000, 280),
#  ('starbucks', 3000, 280),
#  ('starbucks', 3000, 280),
#  ('starbucks', 3000, 280),
#  ('starbucks', 3000, 280),
#  ('mcdonalds', 1000, 270),
#  ('mcdonalds', 1000, 270),
#  ('mcdonalds', 1000, 270),
#  ('mcdonalds', 1000, 270),
#  ('mcdonalds', 1000, 270),
#  ('mcdonalds', 1000, 270),
#  ('starbucks', 3000, 270),
#  ('starbucks', 3000, 270),
#  ('starbucks', 3000, 270),
#  ('starbucks', 3000, 270),
#  ('starbucks', 3000, 270),
#  ('starbucks', 3000, 270),
#  ('mcdonalds', 1000, 260),
#  ('mcdonalds', 1000, 260),
#  ('mcdonalds', 1000, 260),
#  ('mcdonalds', 1000, 260),
#  ('mcdonalds', 1000, 260),
#  ('mcdonalds', 1000, 260),
#  ('mcdonalds', 1000, 260),
#  ('subway', 2000, 260),
#  ('subway', 2000, 260),
#  ('starbucks', 3000, 260),
#  ('starbucks', 3000, 260),
#  ('starbucks', 3000, 260),
#  ('starbucks', 3000, 260),
#  ('starbucks', 3000, 260),
#  ('starbucks', 3000, 260),
#  ('starbucks', 3000, 260),
#  ('starbucks', 3000, 260),
#  ('mcdonalds', 1000, 250),
#  ('mcdonalds', 1000, 250),
#  ('mcdonalds', 1000, 250),
#  ('mcdonalds', 1000, 250),
#  ('mcdonalds', 1000, 250),
#  ('mcdonalds', 1000, 250),
#  ('mcdonalds', 1000, 250),
#  ('mcdonalds', 1000, 250),
#  ('subway', 2000, 250),
#  ('starbucks', 3000, 250),
#  ('starbucks', 3000, 250),
#  ('starbucks', 3000, 250),
#  ('starbucks', 3000, 250),
#  ('starbucks', 3000, 250),
#  ('mcdonalds', 1000, 240),
#  ('mcdonalds', 1000, 240),
#  ('mcdonalds', 1000, 240),
#  ('mcdonalds', 1000, 240),
#  ('subway', 2000, 240),
#  ('starbucks', 3000, 240),
#  ('starbucks', 3000, 240),
#  ('starbucks', 3000, 240),
#  ('starbucks', 3000, 240),
#  ('starbucks', 3000, 240),
#  ('starbucks', 3000, 240),
#  ('starbucks', 3000, 240),
#  ('starbucks', 3000, 240),
#  ('starbucks', 3000, 240),
#  ('starbucks', 3000, 240),
#  ('starbucks', 3000, 240),
#  ('starbucks', 3000, 240),
#  ('starbucks', 3000, 240),
#  ('mcdonalds', 1000, 230),
#  ('mcdonalds', 1000, 230),
#  ('subway', 2000, 230),
#  ('subway', 2000, 230),
#  ('subway', 2000, 230),
#  ('starbucks', 3000, 230),
#  ('starbucks', 3000, 230),
#  ('starbucks', 3000, 230),
#  ('starbucks', 3000, 230),
#  ('starbucks', 3000, 230),
#  ('starbucks', 3000, 230),
#  ('starbucks', 3000, 230),
#  ('mcdonalds', 1000, 220),
#  ('mcdonalds', 1000, 220),
#  ('mcdonalds', 1000, 220),
#  ('mcdonalds', 1000, 220),
#  ('subway', 2000, 220),
#  ('subway', 2000, 220),
#  ('subway', 2000, 220),
#  ('subway', 2000, 220),
#  ('subway', 2000, 220),
#  ('subway', 2000, 220),
#  ('starbucks', 3000, 220),
#  ('starbucks', 3000, 220),
#  ('starbucks', 3000, 220),
#  ('starbucks', 3000, 220),
#  ('starbucks', 3000, 220),
#  ('starbucks', 3000, 220),
#  ('starbucks', 3000, 220),
#  ('starbucks', 3000, 220),
#  ('mcdonalds', 1000, 210),
#  ('mcdonalds', 1000, 210),
#  ('mcdonalds', 1000, 210),
#  ('mcdonalds', 1000, 210),
#  ('subway', 2000, 210),
#  ('subway', 2000, 210),
#  ('subway', 2000, 210),
#  ('subway', 2000, 210),
#  ('subway', 2000, 210),
#  ('subway', 2000, 210),
#  ('subway', 2000, 210),
#  ('subway', 2000, 210),
#  ('starbucks', 3000, 210),
#  ('starbucks', 3000, 210),
#  ('starbucks', 3000, 210),
#  ('starbucks', 3000, 210),
#  ('starbucks', 3000, 210),
#  ('starbucks', 3000, 210),
#  ('starbucks', 3000, 210),
#  ('mcdonalds', 1000, 200),
#  ('mcdonalds', 1000, 200),
#  ('mcdonalds', 1000, 200),
#  ('mcdonalds', 1000, 200),
#  ('subway', 2000, 200),
#  ('subway', 2000, 200),
#  ('subway', 2000, 200),
#  ('subway', 2000, 200),
#  ('subway', 2000, 200),
#  ('starbucks', 3000, 200),
#  ('starbucks', 3000, 200),
#  ('starbucks', 3000, 200),
#  ('starbucks', 3000, 200),
#  ('starbucks', 3000, 200),
#  ('starbucks', 3000, 200),
#  ('starbucks', 3000, 200),
#  ('starbucks', 3000, 200),
#  ('starbucks', 3000, 200),
#  ('starbucks', 3000, 200),
#  ('starbucks', 3000, 200),
#  ('starbucks', 3000, 200),
#  ('mcdonalds', 1000, 190),
#  ('mcdonalds', 1000, 190),
#  ('mcdonalds', 1000, 190),
#  ('mcdonalds', 1000, 190),
#  ('mcdonalds', 1000, 190),
#  ('subway', 2000, 190),
#  ('subway', 2000, 190),
#  ('subway', 2000, 190),
#  ('starbucks', 3000, 190),
#  ('starbucks', 3000, 190),
#  ('starbucks', 3000, 190),
#  ('starbucks', 3000, 190),
#  ('starbucks', 3000, 190),
#  ('starbucks', 3000, 190),
#  ('starbucks', 3000, 190),
#  ('starbucks', 3000, 190),
#  ('starbucks', 3000, 190),
#  ('starbucks', 3000, 190),
#  ('starbucks', 3000, 190),
#  ('starbucks', 3000, 190),
#  ('mcdonalds', 1000, 180),
#  ('mcdonalds', 1000, 180),
#  ('mcdonalds', 1000, 180),
#  ('subway', 2000, 180),
#  ('subway', 2000, 180),
#  ('subway', 2000, 180),
#  ('starbucks', 3000, 180),
#  ('starbucks', 3000, 180),
#  ('starbucks', 3000, 180),
#  ('starbucks', 3000, 180),
#  ('starbucks', 3000, 180),
#  ('starbucks', 3000, 180),
#  ('starbucks', 3000, 180),
#  ('starbucks', 3000, 180),
#  ('starbucks', 3000, 180),
#  ('starbucks', 3000, 180),
#  ('starbucks', 3000, 180),
#  ('starbucks', 3000, 180),
#  ('starbucks', 3000, 180),
#  ('starbucks', 3000, 180),
#  ('starbucks', 3000, 180),
#  ('mcdonalds', 1000, 170),
#  ('mcdonalds', 1000, 170),
#  ('mcdonalds', 1000, 170),
#  ('mcdonalds', 1000, 170),
#  ('subway', 2000, 170),
#  ('subway', 2000, 170),
#  ('starbucks', 3000, 170),
#  ('starbucks', 3000, 170),
#  ('starbucks', 3000, 170),
#  ('starbucks', 3000, 170),
#  ('starbucks', 3000, 170),
#  ('starbucks', 3000, 170),
#  ('starbucks', 3000, 170),
#  ('starbucks', 3000, 170),
#  ('starbucks', 3000, 170),
#  ('starbucks', 3000, 170),
#  ('starbucks', 3000, 170),
#  ('starbucks', 3000, 170),
#  ('starbucks', 3000, 170),
#  ('mcdonalds', 1000, 160),
#  ('mcdonalds', 1000, 160),
#  ('starbucks', 3000, 160),
#  ('starbucks', 3000, 160),
#  ('starbucks', 3000, 160),
#  ('starbucks', 3000, 160),
#  ('starbucks', 3000, 160),
#  ('starbucks', 3000, 160),
#  ('starbucks', 3000, 160),
#  ('starbucks', 3000, 160),
#  ('starbucks', 3000, 160),
#  ('starbucks', 3000, 160),
#  ('mcdonalds', 1000, 150),
#  ('mcdonalds', 1000, 150),
#  ('mcdonalds', 1000, 150),
#  ('mcdonalds', 1000, 150),
#  ('mcdonalds', 1000, 150),
#  ('subway', 2000, 150),
#  ('starbucks', 3000, 150),
#  ('starbucks', 3000, 150),
#  ('starbucks', 3000, 150),
#  ('starbucks', 3000, 150),
#  ('starbucks', 3000, 150),
#  ('starbucks', 3000, 150),
#  ('starbucks', 3000, 150),
#  ('starbucks', 3000, 150),
#  ('starbucks', 3000, 150),
#  ('starbucks', 3000, 150),
#  ('starbucks', 3000, 150),
#  ('mcdonalds', 1000, 140),
#  ('mcdonalds', 1000, 140),
#  ('mcdonalds', 1000, 140),
#  ('mcdonalds', 1000, 140),
#  ('mcdonalds', 1000, 140),
#  ('mcdonalds', 1000, 140),
#  ('mcdonalds', 1000, 140),
#  ('subway', 2000, 140),
#  ('subway', 2000, 140),
#  ('starbucks', 3000, 140),
#  ('starbucks', 3000, 140),
#  ('starbucks', 3000, 140),
#  ('starbucks', 3000, 140),
#  ('starbucks', 3000, 140),
#  ('mcdonalds', 1000, 130),
#  ('mcdonalds', 1000, 130),
#  ('mcdonalds', 1000, 130),
#  ('mcdonalds', 1000, 130),
#  ('subway', 2000, 130),
#  ('starbucks', 3000, 130),
#  ('starbucks', 3000, 130),
#  ('starbucks', 3000, 130),
#  ('starbucks', 3000, 130),
#  ('starbucks', 3000, 130),
#  ('starbucks', 3000, 130),
#  ('starbucks', 3000, 130),
#  ('starbucks', 3000, 130),
#  ('starbucks', 3000, 130),
#  ('starbucks', 3000, 130),
#  ('starbucks', 3000, 130),
#  ('mcdonalds', 1000, 120),
#  ('mcdonalds', 1000, 120),
#  ('subway', 2000, 120),
#  ('subway', 2000, 120),
#  ('subway', 2000, 120),
#  ('starbucks', 3000, 120),
#  ('starbucks', 3000, 120),
#  ('starbucks', 3000, 120),
#  ('starbucks', 3000, 120),
#  ('starbucks', 3000, 120),
#  ('starbucks', 3000, 120),
#  ('starbucks', 3000, 120),
#  ('starbucks', 3000, 120),
#  ('starbucks', 3000, 120),
#  ('starbucks', 3000, 120),
#  ('starbucks', 3000, 120),
#  ('mcdonalds', 1000, 110),
#  ('mcdonalds', 1000, 110),
#  ('subway', 2000, 110),
#  ('starbucks', 3000, 110),
#  ('starbucks', 3000, 110),
#  ('starbucks', 3000, 110),
#  ('starbucks', 3000, 110),
#  ('starbucks', 3000, 110),
#  ('starbucks', 3000, 110),
#  ('starbucks', 3000, 110),
#  ('starbucks', 3000, 110),
#  ('starbucks', 3000, 110),
#  ('mcdonalds', 1000, 100),
#  ('mcdonalds', 1000, 100),
#  ('mcdonalds', 1000, 100),
#  ('mcdonalds', 1000, 100),
#  ('mcdonalds', 1000, 100),
#  ('subway', 2000, 100),
#  ('starbucks', 3000, 100),
#  ('starbucks', 3000, 100),
#  ('starbucks', 3000, 100),
#  ('starbucks', 3000, 100),
#  ('starbucks', 3000, 100),
#  ('starbucks', 3000, 100),
#  ('starbucks', 3000, 100),
#  ('starbucks', 3000, 100),
#  ('starbucks', 3000, 100),
#  ('starbucks', 3000, 100),
#  ('starbucks', 3000, 100),
#  ('starbucks', 3000, 90),
#  ('starbucks', 3000, 90),
#  ('starbucks', 3000, 90),
#  ('starbucks', 3000, 90),
#  ('starbucks', 3000, 90),
#  ('starbucks', 3000, 90),
#  ('starbucks', 3000, 90),
#  ('starbucks', 3000, 90),
#  ('starbucks', 3000, 90),
#  ('mcdonalds', 1000, 80),
#  ('mcdonalds', 1000, 80),
#  ('subway', 2000, 80),
#  ('subway', 2000, 80),
#  ('subway', 2000, 80),
#  ('starbucks', 3000, 80),
#  ('starbucks', 3000, 80),
#  ('starbucks', 3000, 80),
#  ('starbucks', 3000, 80),
#  ('starbucks', 3000, 80),
#  ('starbucks', 3000, 80),
#  ('starbucks', 3000, 80),
#  ('starbucks', 3000, 80),
#  ('starbucks', 3000, 80),
#  ('subway', 2000, 70),
#  ('subway', 2000, 70),
#  ('subway', 2000, 70),
#  ('subway', 2000, 70),
#  ('starbucks', 3000, 70),
#  ('starbucks', 3000, 70),
#  ('starbucks', 3000, 70),
#  ('subway', 2000, 60),
#  ('subway', 2000, 60),
#  ('subway', 2000, 60),
#  ('starbucks', 3000, 60),
#  ('starbucks', 3000, 60),
#  ('starbucks', 3000, 60),
#  ('starbucks', 3000, 60),
#  ('subway', 2000, 50),
#  ('subway', 2000, 50),
#  ('subway', 2000, 50),
#  ('subway', 2000, 50),
#  ('subway', 2000, 50),
#  ('subway', 2000, 50),
#  ('starbucks', 3000, 50),
#  ('starbucks', 3000, 50),
#  ('mcdonalds', 1000, 45),
#  ('subway', 2000, 45),
#  ('subway', 2000, 40),
#  ('subway', 2000, 40),
#  ('subway', 2000, 35),
#  ('subway', 2000, 30),
#  ('starbucks', 3000, 25),
#  ('mcdonalds', 1000, 20),
#  ('subway', 2000, 20),
#  ('mcdonalds', 1000, 15),
#  ('subway', 2000, 15),
#  ('starbucks', 3000, 15),
#  ('subway', 2000, 10),
#  ('starbucks', 3000, 10),
#  ('starbucks', 3000, 10),
#  ('subway', 2000, 5),
#  ('subway', 2000, 5),
#  ('starbucks', 3000, 5),
#  ('starbucks', 3000, 5),
#  ('starbucks', 3000, 5),
#  ('starbucks', 3000, 5),
#  ('starbucks', 3000, 4),
#  ('starbucks', 3000, 3),
#  ('mcdonalds', 1000, 0),
#  ('mcdonalds', 1000, 0),
#  ('mcdonalds', 1000, 0),
#  ('mcdonalds', 1000, 0),
#  ('mcdonalds', 1000, 0),
#  ('mcdonalds', 1000, 0),
#  ('mcdonalds', 1000, 0),
#  ('mcdonalds', 1000, 0),
#  ('mcdonalds', 1000, 0),
#  ('mcdonalds', 1000, 0),
#  ('mcdonalds', 1000, 0),
#  ('mcdonalds', 1000, 0),
#  ('mcdonalds', 1000, 0),
#  ('mcdonalds', 1000, 0),
#  ('mcdonalds', 1000, 0),
#  ('mcdonalds', 1000, 0),
#  ('subway', 2000, 0),
#  ('subway', 2000, 0),
#  ('subway', 2000, 0),
#  ('subway', 2000, 0),
#  ('subway', 2000, 0),
#  ('subway', 2000, 0),
#  ('subway', 2000, 0),
#  ('subway', 2000, 0),
#  ('subway', 2000, 0),
#  ('subway', 2000, 0),
#  ('starbucks', 3000, 0),
#  ('starbucks', 3000, 0),
#  ('starbucks', 3000, 0),
#  ('starbucks', 3000, 0)]

# %%
# Category counts (still can't figure out how to link it to restaurant name) 
# Testing out setting id's to be equal across tables to get the category name to show up

sel = [Categories.category_name, func.count(Nutrition.category_id)]

category_counts = session.query(*sel).filter(Nutrition.category_id==Categories.id).\
    group_by(Nutrition.category_id).\
    order_by(func.count(Nutrition.category_id).desc()).all()

category_counts
# Out:
# [('Breakfast', 98),
#  ('Coffee & Tea', 95),
#  ('Classic Espresso Drinks', 58),
#  ('Tazo® Tea Drinks', 52),
#  ('Signature Espresso Drinks', 40),
#  ('Other Food', 36),
#  ('Frappuccino® Blended Coffee', 36),
#  ('Sandwich', 31),
#  ('Smoothies & Shakes', 28),
#  ('Beverages', 27),
#  ('Chicken & Fish', 27),
#  ('Desert', 25),
#  ('Wrap', 20),
#  ('Shaken Iced Beverages', 18),
#  ('Salad', 18),
#  ('Bread', 15),
#  ('Beef & Pork', 15),
#  ('Frappuccino® Blended Crème', 13),
#  ('Extra', 13),
#  ('Snacks & Sides', 13),
#  ('Frappuccino® Light Blended Coffee', 12),
#  ('Sauces', 12),
#  ('Veggies', 10),
#  ('Smoothies', 9),
#  ('Cheese', 7),
#  ('Desserts', 7),
#  ('Salads', 6),
#  ('Coffee', 4),
#  ('Extras', 3),
#  ('Seasonings', 1),
#  ('Protein', 1)]

# %%
# Find the breakfast items with more than 400 calories in the restaurant menu
# Testing out setting id's to be equal across tables to get the the restaurant & items to show up

sel = [Restaurants.name, Menu_items.item_name, Nutrition.restaurant_id, Nutrition.calories]

breakfast_calories = session.query(*sel).filter(Nutrition.restaurant_id==Restaurants.id).\
filter(Nutrition.item_id==Menu_items.id).\
filter(Nutrition.calories > 400).\
order_by(Nutrition.calories.desc()).all()
#order_by.filter(Nutrition.calories > '400').desc().all()

breakfast_calories
# Out:
# [('mcdonalds', 'Chicken McNuggets (40 piece)', 1000, 1880),
#  ('subway', 'Chicken & Bacon Ranch Melt-Wrap', 2000, 1590),
#  ('mcdonalds', 'Big Breakfast with Hotcakes (Large Biscuit)', 1000, 1150),
#  ('mcdonalds', 'Big Breakfast with Hotcakes (Regular Biscuit)', 1000, 1090),
#  ('subway', 'BBQ Rib Signature Wrap-Wrap', 2000, 1080),
#  ('mcdonalds',
#   'Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)',
#   1000,
#   1050),
#  ('mcdonalds',
#   'Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)',
#   1000,
#   990),
#  ('mcdonalds', 'Chicken McNuggets (20 piece)', 1000, 940),
#  ('mcdonalds', 'McFlurry with M&M’s Candies (Medium)', 1000, 930),
#  ('mcdonalds', 'Strawberry Shake (Large)', 1000, 850),
#  ('mcdonalds', 'Chocolate Shake (Large)', 1000, 850),
#  ('mcdonalds', 'Vanilla Shake (Large)', 1000, 820),
#  ('mcdonalds', 'Shamrock Shake (Large)', 1000, 820),
#  ('subway', 'Cripsy Cauliflower Ranch Signature Wrap-Wrap', 2000, 820),
#  ('subway', 'Spicy Italian-Wrap', 2000, 820),
#  ('subway', 'Tuna-Wrap', 2000, 820),
#  ('mcdonalds', "McFlurry with Reese's Peanut Butter Cups (Medium)", 1000, 810),
#  ('mcdonalds', 'Big Breakfast (Large Biscuit)', 1000, 800),
#  ('subway', 'Cauliflower Fritter Curry Signature Wrap-Wrap', 2000, 790),
#  ('subway', 'Turkey & Bacon Guacamole-Sandwich', 2000, 780),
#  ('subway', 'Southwest Chipotle Chicken Club-Salad', 2000, 780),
#  ('subway', 'Meatball Marinara-Wrap', 2000, 770),
#  ('mcdonalds', 'Frappé Chocolate Chip (Large)', 1000, 760),
#  ('subway', 'Turkey, Bacon & Guacamole-Wrap', 2000, 760),
#  ('mcdonalds', 'Double Quarter Pounder with Cheese', 1000, 750),
#  ('mcdonalds', 'Bacon Clubhouse Crispy Chicken Sandwich', 1000, 750),
#  ('mcdonalds', 'Big Breakfast (Regular Biscuit)', 1000, 740),
#  ('subway', 'Ultimate Spicy Italian-Sandwich', 2000, 730),
#  ('mcdonalds', 'Bacon Clubhouse Burger', 1000, 720),
#  ('subway', 'Ultimate Meatball Marinara-Sandwich', 2000, 720),
#  ('subway', 'Chipotle Southwest Steak & Cheese-Wrap', 2000, 710),
#  ('mcdonalds', 'Chocolate Shake (Medium)', 1000, 700),
#  ('mcdonalds', 'Big Breakfast with Egg Whites (Large Biscuit)', 1000, 690),
#  ('mcdonalds', 'Strawberry Shake (Medium)', 1000, 690),
#  ('mcdonalds', 'McFlurry with Oreo Cookies (Medium)', 1000, 690),
#  ('subway', 'Italian B.M.T. ®-Wrap', 2000, 680),
#  ('subway', 'Savory Rotisserie-Style Chicken Caesar-Wrap', 2000, 680),
#  ('mcdonalds', 'Steak, Egg & Cheese Bagel', 1000, 670),
#  ('mcdonalds', 'Premium Crispy Chicken Club Sandwich', 1000, 670),
#  ('mcdonalds', 'Premium McWrap Southwest Chicken (Crispy Chicken)', 1000, 670),
#  ('mcdonalds', 'Frappé Mocha (Large)', 1000, 670),
#  ('mcdonalds', 'Frappé Caramel (Large)', 1000, 670),
#  ('mcdonalds', 'Vanilla Shake (Medium)', 1000, 660),
#  ('mcdonalds', 'Shamrock Shake (Medium)', 1000, 660),
#  ('mcdonalds', 'McFlurry with M&M’s Candies (Small)', 1000, 650),
#  ('starbucks', 'Lentils & Vegetable Protein Bowl with Brown Rice', 3000, 650),
#  ('mcdonalds', 'Big Breakfast with Egg Whites (Regular Biscuit)', 1000, 640),
#  ('mcdonalds', 'Premium McWrap Chicken & Bacon (Crispy Chicken)', 1000, 630),
#  ('mcdonalds', 'Frappé Chocolate Chip (Medium)', 1000, 630),
#  ('mcdonalds', 'Bacon, Egg & Cheese Bagel', 1000, 620),
#  ('starbucks', 'Green Goddess Avocado Salad', 3000, 620),
#  ('mcdonalds', 'Quarter Pounder with Bacon Habanero Ranch', 1000, 610),
#  ('mcdonalds', 'Premium Crispy Chicken Ranch BLT Sandwich', 1000, 610),
#  ('mcdonalds', 'Premium McWrap Chicken & Ranch (Crispy Chicken)', 1000, 610),
#  ('mcdonalds', 'Quarter Pounder with Bacon & Cheese', 1000, 600),
#  ('subway', 'Ultimate Steak-Sandwich', 2000, 600),
#  ('starbucks', 'Strawberries & Jam Sandwich', 3000, 600),
#  ('starbucks', 'Roasted Turkey & Dill Havarti Sandwich', 3000, 600),
#  ('mcdonalds', 'Bacon Clubhouse Grilled Chicken Sandwich', 1000, 590),
#  ('subway', 'BBQ Rib-Sandwich', 2000, 580),
#  ('mcdonalds', 'Sausage Biscuit with Egg (Large Biscuit)', 1000, 570),
#  ('mcdonalds', 'Bacon, Egg & Cheese Bagel with Egg Whites', 1000, 570),
#  ('subway', 'Paneer Tikka-Sandwich', 2000, 570),
#  ('starbucks', "Za'atar Chicken & Lemon Tahini Salad", 3000, 570),
#  ('mcdonalds', 'Chocolate Shake (Small)', 1000, 560),
#  ('subway', 'Cold Cut Combo-Wrap', 2000, 560),
#  ('starbucks', 'Turkey & Fire-Roasted Corn Salad', 3000, 560),
#  ('starbucks', 'Turkey Pesto Panini', 3000, 560),
#  ('mcdonalds', 'Sausage, Egg & Cheese McGriddles', 1000, 550),
#  ('mcdonalds', 'Frappé Mocha (Medium)', 1000, 550),
#  ('mcdonalds', 'Frappé Caramel (Medium)', 1000, 550),
#  ('mcdonalds', 'Strawberry Shake (Small)', 1000, 550),
#  ('subway', 'Southwest Chicken Club-Sandwich', 2000, 550),
#  ('subway', 'Rotisserie-Style Chicken-Wrap', 2000, 550),
#  ('mcdonalds', 'Steak & Egg Biscuit (Regular Biscuit)', 1000, 540),
#  ('mcdonalds', 'Quarter Pounder Deluxe', 1000, 540),
#  ('mcdonalds',
#   'Premium McWrap Chicken Sweet Chili (Crispy Chicken)',
#   1000,
#   540),
#  ('mcdonalds', 'Hot Chocolate (Large)', 1000, 540),
#  ('subway', 'Sweet Onion Chicken Teriyaki-Wrap', 2000, 540),
#  ('mcdonalds', 'Big Mac', 1000, 530),
#  ('mcdonalds', 'Frappé Chocolate Chip (Small)', 1000, 530),
#  ('mcdonalds', 'Vanilla Shake (Small)', 1000, 530),
#  ('subway', 'Chicken & Bacon Ranch Melt-Sandwich', 2000, 530),
#  ('starbucks', 'Seared Steak & Cheddar Sandwich', 3000, 530),
#  ('mcdonalds', 'Bacon, Egg & Cheese Biscuit (Large Biscuit)', 1000, 520),
#  ('mcdonalds', 'Sausage Biscuit with Egg Whites (Large Biscuit)', 1000, 520),
#  ('mcdonalds', 'Hotcakes and Sausage', 1000, 520),
#  ('mcdonalds', 'Quarter Pounder with Cheese', 1000, 520),
#  ('mcdonalds',
#   'Premium McWrap Southwest Chicken (Grilled Chicken)',
#   1000,
#   520),
#  ('starbucks', 'PB&J Protein Box', 3000, 520),
#  ('mcdonalds', 'Sausage Biscuit with Egg (Regular Biscuit)', 1000, 510),
#  ('mcdonalds', 'Premium Crispy Chicken Classic Sandwich', 1000, 510),
#  ('mcdonalds', 'Premium Grilled Chicken Club Sandwich', 1000, 510),
#  ('mcdonalds', 'Large French Fries', 1000, 510),
#  ('mcdonalds', 'McFlurry with Oreo Cookies (Small)', 1000, 510),
#  ('starbucks',
#   'White Chocolate Mocha (Without Whipped Cream)-Venti 2% Milk',
#   3000,
#   510),
#  ('starbucks', 'Chicken Artichoke on Ancient Grain Flatbread', 3000, 510),
#  ('mcdonalds', 'Sausage, Egg & Cheese McGriddles with Egg Whites', 1000, 500),
#  ('mcdonalds', 'McRib', 1000, 500),
#  ('mcdonalds', 'Mocha (Large)', 1000, 500),
#  ('starbucks', 'Smoked Mozzarella & Roasted Pepper Sandwich', 3000, 500),
#  ('starbucks', 'Sausage Cheddar & Egg Breakfast Sandwich', 3000, 500),
#  ('starbucks',
#   'Spicy Chorizo  Monterey Jack & Egg Breakfast Sandwich',
#   3000,
#   500),
#  ('starbucks', 'Ancho Chipotle Chicken Panini', 3000, 500),
#  ('subway', 'Steak Club-Sandwich', 2000, 490),
#  ('subway', 'Roast Beef-Wrap', 2000, 490),
#  ('subway', 'Subway Club®-Wrap', 2000, 490),
#  ('starbucks', 'Chocolate Marble Loaf Cake', 3000, 490),
#  ('starbucks', 'Double Chocolate Chunk Brownie', 3000, 490),
#  ('starbucks', 'Double-Smoked Bacon Cheddar & Egg Sandwich', 3000, 490),
#  ('mcdonalds', 'Sausage Biscuit (Large Biscuit)', 1000, 480),
#  ('mcdonalds', 'Bacon Cheddar McChicken', 1000, 480),
#  ('mcdonalds', 'Premium McWrap Chicken & Bacon (Grilled Chicken)', 1000, 480),
#  ('mcdonalds', 'Caramel Mocha (Large)', 1000, 480),
#  ('mcdonalds', 'Iced Mocha (Large)', 1000, 480),
#  ('subway', 'Steak Club Salad-Salad', 2000, 480),
#  ('starbucks', 'Old-Fashioned Glazed Doughnut', 3000, 480),
#  ('starbucks', 'Egg Salad Sandwich', 3000, 480),
#  ('starbucks', 'Homestyle Chicken & Double-Smoked Bacon', 3000, 480),
#  ('starbucks', 'Italian-Style Ham & Spicy Salami', 3000, 480),
#  ('mcdonalds',
#   'Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)',
#   1000,
#   470),
#  ('mcdonalds', 'Southern Style Chicken Biscuit (Large Biscuit)', 1000, 470),
#  ('mcdonalds', 'Chicken McNuggets (10 piece)', 1000, 470),
#  ('starbucks', 'Iced Lemon Pound Cake', 3000, 470),
#  ('starbucks', "Farmers' Market Protein Box", 3000, 470),
#  ('starbucks', 'Chicken BLT Salad Sandwich', 3000, 470),
#  ('mcdonalds', 'Bacon, Egg & Cheese Biscuit (Regular Biscuit)', 1000, 460),
#  ('mcdonalds', 'Sausage Biscuit with Egg Whites (Regular Biscuit)', 1000, 460),
#  ('mcdonalds', 'Bacon, Egg & Cheese McGriddles', 1000, 460),
#  ('mcdonalds', 'Cinnamon Melts', 1000, 460),
#  ('mcdonalds', 'Iced Caramel Mocha (Large)', 1000, 460),
#  ('subway', 'Chicken & Bacon Ranch-Salad', 2000, 460),
#  ('subway', 'Oven Roasted Chicken-Wrap', 2000, 460),
#  ('starbucks',
#   'White Chocolate Mocha (Without Whipped Cream)-Venti Soymilk',
#   3000,
#   460),
#  ('starbucks',
#   'Java Chip (Without Whipped Cream)-Venti  Whole Milk',
#   3000,
#   460),
#  ('starbucks', 'Apple Fritter', 3000, 460),
#  ('starbucks', 'Chicken Wrap Protein Box', 3000, 460),
#  ('starbucks', 'Eggs & Cheese Protein Box', 3000, 460),
#  ('starbucks', 'Turkey & Havarti Sandwich', 3000, 460),
#  ('mcdonalds', 'Sausage McMuffin with Egg', 1000, 450),
#  ('mcdonalds', 'Premium Grilled Chicken Ranch BLT Sandwich', 1000, 450),
#  ('mcdonalds', 'Premium McWrap Chicken & Ranch (Grilled Chicken)', 1000, 450),
#  ('mcdonalds', 'Premium Southwest Salad with Crispy Chicken', 1000, 450),
#  ('mcdonalds', 'Frappé Mocha (Small)', 1000, 450),
#  ('mcdonalds', 'Frappé Caramel (Small)', 1000, 450),
#  ('subway', 'Classic Tuna-Sandwich', 2000, 450),
#  ('subway', 'Spicy Italian-Sandwich', 2000, 450),
#  ('subway', 'Bacon, Egg & Cheese-Breakfast', 2000, 450),
#  ('starbucks',
#   'White Chocolate Mocha (Without Whipped Cream)-Venti Nonfat Milk',
#   3000,
#   450),
#  ('starbucks', 'Tazo® Green Tea Latte-Venti 2% Milk', 3000, 450),
#  ('starbucks', 'Cheese & Fruit Protein Box', 3000, 450),
#  ('starbucks', 'Slow-Roasted Ham Swiss & Egg Breakfast Sandwich', 3000, 450),
#  ('mcdonalds', 'Bacon McDouble', 1000, 440),
#  ('mcdonalds', 'Hot Chocolate (Medium)', 1000, 440),
#  ('subway', 'BBQ Rib-Salad', 2000, 440),
#  ('subway', 'Steak, Egg & Cheese-Breakfast', 2000, 440),
#  ('subway', 'Black Forest Ham-Wrap', 2000, 440),
#  ('starbucks', 'Chocolate Chunk Muffin', 3000, 440),
#  ('starbucks', 'Double Chocolate Loaf Cake', 3000, 440),
#  ('starbucks', 'Roasted Carrot & Kale Side Salad', 3000, 440),
#  ('mcdonalds', 'Steak & Egg McMuffin', 1000, 430),
#  ('mcdonalds', 'Sausage Biscuit (Regular Biscuit)', 1000, 430),
#  ('mcdonalds', 'Double Cheeseburger', 1000, 430),
#  ('mcdonalds', 'Daily Double', 1000, 430),
#  ('mcdonalds', 'Jalapeño Double', 1000, 430),
#  ('mcdonalds', 'Southern Style Crispy Chicken Sandwich', 1000, 430),
#  ('mcdonalds', 'Bacon Buffalo Ranch McChicken', 1000, 430),
#  ('mcdonalds', 'Caramel Latte (Large)', 1000, 430),
#  ('mcdonalds', 'Hazelnut Latte (Large)', 1000, 430),
#  ('mcdonalds', 'McFlurry with M&M’s Candies (Snack)', 1000, 430),
#  ('subway', 'Genoa Salami-Sandwich', 2000, 430),
#  ('subway', 'Turkey Breast-Wrap', 2000, 430),
#  ('starbucks', 'Java Chip (Without Whipped Cream)-Venti Soymilk', 3000, 430),
#  ('starbucks', "Devil's Food Doughnut", 3000, 430),
#  ('starbucks', 'Cubano Sandwich', 3000, 430),
#  ('mcdonalds', 'Sausage McGriddles', 1000, 420),
#  ('mcdonalds', 'French Vanilla Latte (Large)', 1000, 420),
#  ('subway', 'Meatball Marinara-Sandwich', 2000, 420),
#  ('starbucks',
#   'Java Chip (Without Whipped Cream)-Venti Nonfat Milk',
#   3000,
#   420),
#  ('starbucks', 'Banana Nut Bread', 3000, 420),
#  ('starbucks', 'Blueberry Scone', 3000, 420),
#  ('starbucks', 'Cranberry Orange Scone', 3000, 420),
#  ('starbucks', 'Raspberry Swirl Loaf Cake', 3000, 420),
#  ('starbucks', 'BBQ Chicken Protein Box', 3000, 420),
#  ('starbucks',
#   'Chicken & Quinoa Protein Bowl with Black Beans and Greens',
#   3000,
#   420),
#  ('starbucks', 'Roasted Tomato & Mozzarella Panini', 3000, 420),
#  ('mcdonalds',
#   'Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)',
#   1000,
#   410),
#  ('mcdonalds', 'Southern Style Chicken Biscuit (Regular Biscuit)', 1000, 410),
#  ('mcdonalds', 'Mocha (Medium)', 1000, 410),
#  ('mcdonalds', "McFlurry with Reese's Peanut Butter Cups (Snack)", 1000, 410),
#  ('subway', 'Black Forest Ham, Egg & Cheese-Breakfast', 2000, 410),
#  ('starbucks', 'Almond Croissant', 3000, 410),
#  ('starbucks', 'Double Chocolate Brownie', 3000, 410),
#  ('starbucks', 'Pumpkin Bread', 3000, 410),
#  ('starbucks', 'Seared Steak Egg & Tomatillo Wrap', 3000, 410)]

# %%
# Display the query results
print("These are the breaskfast with the most calories:")

for item_info in breakfast_calories:
    (restaurant, item, total_calories) = item_info
    print(f"The breakfast {item} from {restaurant} has {total_calories} in total.")
# Out:
# These are the breaskfast with the most calories:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-2ec90e2a5733> in <module>
#       3
#       4 for item_info in breakfast_calories:
# ----> 5     (restaurant, item, total_calories) = item_info
#       6     print(f"The breakfast {item} from {restaurant} has {total_calories} in total.")
#
# ValueError: too many values to unpack (expected 3)
